# %%
# %run Classes.ipynb

# %%
filter_model = FilterData()

# %% [markdown]
# **KL855 AMS --> ICN**

# %%
departure_airport = 'AMS'
arrival_airport = 'ICN'
month = 'JAN'
year = '2024'

results_reader = ResultsReader(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_results(df)
# Out:
# <style type="text/css">
# #T_7344b th.col-1 {
#   text-align: left;
# }
# #T_7344b td.col-1 {
#   text-align: center;
# }
# #T_7344b_row0_col0, #T_7344b_row1_col0, #T_7344b_row2_col0, #T_7344b_row3_col0, #T_7344b_row4_col0, #T_7344b_row5_col0, #T_7344b_row6_col0, #T_7344b_row7_col0, #T_7344b_row8_col0, #T_7344b_row9_col0, #T_7344b_row10_col0, #T_7344b_row11_col0, #T_7344b_row12_col0, #T_7344b_row13_col0, #T_7344b_row14_col0, #T_7344b_row15_col0 {
#   text-align: left;
# }
# #T_7344b_row16_col0, #T_7344b_row17_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %%
departure_airport = 'AMS'
arrival_airport = 'ICN'
month = 'FEB'
year = '2024'

results_reader = ResultsReader(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_results(df)
# Out:
# <style type="text/css">
# #T_9f266 th.col-1 {
#   text-align: left;
# }
# #T_9f266 td.col-1 {
#   text-align: center;
# }
# #T_9f266_row0_col0, #T_9f266_row1_col0, #T_9f266_row2_col0, #T_9f266_row3_col0, #T_9f266_row4_col0, #T_9f266_row5_col0, #T_9f266_row6_col0, #T_9f266_row7_col0, #T_9f266_row8_col0, #T_9f266_row9_col0, #T_9f266_row10_col0, #T_9f266_row11_col0, #T_9f266_row12_col0, #T_9f266_row13_col0, #T_9f266_row14_col0, #T_9f266_row15_col0 {
#   text-align: left;
# }
# #T_9f266_row16_col0, #T_9f266_row17_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %%
departure_airport = 'AMS'
arrival_airport = 'ICN'
month = 'MAR'
year = '2024'

results_reader = ResultsReader(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_results(df)
# Out:
# <style type="text/css">
# #T_3c116 th.col-1 {
#   text-align: left;
# }
# #T_3c116 td.col-1 {
#   text-align: center;
# }
# #T_3c116_row0_col0, #T_3c116_row1_col0, #T_3c116_row2_col0, #T_3c116_row3_col0, #T_3c116_row4_col0, #T_3c116_row5_col0, #T_3c116_row6_col0, #T_3c116_row7_col0, #T_3c116_row8_col0, #T_3c116_row9_col0, #T_3c116_row10_col0, #T_3c116_row11_col0, #T_3c116_row12_col0, #T_3c116_row13_col0, #T_3c116_row14_col0, #T_3c116_row15_col0 {
#   text-align: left;
# }
# #T_3c116_row16_col0, #T_3c116_row17_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %% [markdown]
# **KL661 AMS --> IAH**

# %%
departure_airport = 'AMS'
arrival_airport = 'IAH'
month = 'JAN'
year = '2024'

results_reader = ResultsReader(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_results(df)
# Out:
# <style type="text/css">
# #T_14076 th.col-1 {
#   text-align: left;
# }
# #T_14076 td.col-1 {
#   text-align: center;
# }
# #T_14076_row0_col0, #T_14076_row1_col0, #T_14076_row2_col0, #T_14076_row3_col0, #T_14076_row4_col0, #T_14076_row5_col0, #T_14076_row6_col0, #T_14076_row7_col0, #T_14076_row8_col0, #T_14076_row9_col0, #T_14076_row10_col0, #T_14076_row11_col0, #T_14076_row12_col0, #T_14076_row13_col0, #T_14076_row14_col0, #T_14076_row15_col0, #T_14076_row16_col0, #T_14076_row17_col0 {
#   text-align: left;
# }
# #T_14076_row18_col0, #T_14076_row19_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %%
departure_airport = 'AMS'
arrival_airport = 'IAH'
month = 'FEB'
year = '2024'

results_reader = ResultsReader(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_results(df)
# Out:
# <style type="text/css">
# #T_c670b th.col-1 {
#   text-align: left;
# }
# #T_c670b td.col-1 {
#   text-align: center;
# }
# #T_c670b_row0_col0, #T_c670b_row1_col0, #T_c670b_row2_col0, #T_c670b_row3_col0, #T_c670b_row4_col0, #T_c670b_row5_col0, #T_c670b_row6_col0, #T_c670b_row7_col0, #T_c670b_row8_col0, #T_c670b_row9_col0, #T_c670b_row10_col0, #T_c670b_row11_col0, #T_c670b_row12_col0, #T_c670b_row13_col0, #T_c670b_row14_col0 {
#   text-align: left;
# }
# #T_c670b_row15_col0, #T_c670b_row16_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %%
departure_airport = 'AMS'
arrival_airport = 'IAH'
month = 'MAR'
year = '2024'

results_reader = ResultsReader(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_results(df)
# Out:
# <style type="text/css">
# #T_206ec th.col-1 {
#   text-align: left;
# }
# #T_206ec td.col-1 {
#   text-align: center;
# }
# #T_206ec_row0_col0, #T_206ec_row1_col0, #T_206ec_row2_col0, #T_206ec_row3_col0, #T_206ec_row4_col0, #T_206ec_row5_col0, #T_206ec_row6_col0, #T_206ec_row7_col0, #T_206ec_row8_col0, #T_206ec_row9_col0, #T_206ec_row10_col0, #T_206ec_row11_col0, #T_206ec_row12_col0, #T_206ec_row13_col0, #T_206ec_row14_col0 {
#   text-align: left;
# }
# #T_206ec_row15_col0, #T_206ec_row16_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %% [markdown]
# **KL835 AMS --> SIN**

# %%
departure_airport = 'AMS'
arrival_airport = 'SIN'
month = 'JAN'
year = '2024'

results_reader = ResultsReader(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_results(df)
# Out:
# <style type="text/css">
# #T_113b5 th.col-1 {
#   text-align: left;
# }
# #T_113b5 td.col-1 {
#   text-align: center;
# }
# #T_113b5_row0_col0, #T_113b5_row1_col0, #T_113b5_row2_col0, #T_113b5_row3_col0, #T_113b5_row4_col0, #T_113b5_row5_col0, #T_113b5_row6_col0, #T_113b5_row7_col0, #T_113b5_row8_col0, #T_113b5_row9_col0, #T_113b5_row10_col0, #T_113b5_row11_col0, #T_113b5_row12_col0, #T_113b5_row13_col0, #T_113b5_row14_col0, #T_113b5_row15_col0, #T_113b5_row16_col0, #T_113b5_row17_col0, #T_113b5_row18_col0, #T_113b5_row19_col0, #T_113b5_row20_col0, #T_113b5_row21_col0, #T_113b5_row22_col0 {
#   text-align: left;
# }
# #T_113b5_row23_col0, #T_113b5_row24_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %%
departure_airport = 'AMS'
arrival_airport = 'SIN'
month = 'FEB'
year = '2024'

results_reader = ResultsReader(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_results(df)
# Out:
# <style type="text/css">
# #T_58e4a th.col-1 {
#   text-align: left;
# }
# #T_58e4a td.col-1 {
#   text-align: center;
# }
# #T_58e4a_row0_col0, #T_58e4a_row1_col0, #T_58e4a_row2_col0, #T_58e4a_row3_col0, #T_58e4a_row4_col0, #T_58e4a_row5_col0, #T_58e4a_row6_col0, #T_58e4a_row7_col0, #T_58e4a_row8_col0, #T_58e4a_row9_col0, #T_58e4a_row10_col0, #T_58e4a_row11_col0, #T_58e4a_row12_col0, #T_58e4a_row13_col0, #T_58e4a_row14_col0, #T_58e4a_row15_col0, #T_58e4a_row16_col0 {
#   text-align: left;
# }
# #T_58e4a_row17_col0, #T_58e4a_row18_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %%
departure_airport = 'AMS'
arrival_airport = 'SIN'
month = 'MAR'
year = '2024'

results_reader = ResultsReader(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_results(df)
# Out:
# <style type="text/css">
# #T_c7bd8 th.col-1 {
#   text-align: left;
# }
# #T_c7bd8 td.col-1 {
#   text-align: center;
# }
# #T_c7bd8_row0_col0, #T_c7bd8_row1_col0, #T_c7bd8_row2_col0, #T_c7bd8_row3_col0, #T_c7bd8_row4_col0, #T_c7bd8_row5_col0, #T_c7bd8_row6_col0, #T_c7bd8_row7_col0, #T_c7bd8_row8_col0, #T_c7bd8_row9_col0, #T_c7bd8_row10_col0, #T_c7bd8_row11_col0, #T_c7bd8_row12_col0, #T_c7bd8_row13_col0, #T_c7bd8_row14_col0 {
#   text-align: left;
# }
# #T_c7bd8_row15_col0, #T_c7bd8_row16_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %% [markdown]
# **KL601 AMS --> LAX**

# %%
departure_airport = 'AMS'
arrival_airport = 'LAX'
month = 'JAN'
year = '2024'

results_reader = ResultsReader(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_results(df)
# Out:
# <style type="text/css">
# #T_036e6 th.col-1 {
#   text-align: left;
# }
# #T_036e6 td.col-1 {
#   text-align: center;
# }
# #T_036e6_row0_col0, #T_036e6_row1_col0, #T_036e6_row2_col0, #T_036e6_row3_col0, #T_036e6_row4_col0, #T_036e6_row5_col0, #T_036e6_row6_col0, #T_036e6_row7_col0, #T_036e6_row8_col0, #T_036e6_row9_col0, #T_036e6_row10_col0, #T_036e6_row11_col0, #T_036e6_row12_col0, #T_036e6_row13_col0, #T_036e6_row14_col0, #T_036e6_row15_col0, #T_036e6_row16_col0 {
#   text-align: left;
# }
# #T_036e6_row17_col0, #T_036e6_row18_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %%
departure_airport = 'AMS'
arrival_airport = 'LAX'
month = 'FEB'
year = '2024'

results_reader = ResultsReader(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_results(df)
# Out:
# <style type="text/css">
# #T_d4136 th.col-1 {
#   text-align: left;
# }
# #T_d4136 td.col-1 {
#   text-align: center;
# }
# #T_d4136_row0_col0, #T_d4136_row1_col0, #T_d4136_row2_col0, #T_d4136_row3_col0, #T_d4136_row4_col0, #T_d4136_row5_col0, #T_d4136_row6_col0, #T_d4136_row7_col0, #T_d4136_row8_col0, #T_d4136_row9_col0, #T_d4136_row10_col0, #T_d4136_row11_col0, #T_d4136_row12_col0, #T_d4136_row13_col0, #T_d4136_row14_col0, #T_d4136_row15_col0, #T_d4136_row16_col0 {
#   text-align: left;
# }
# #T_d4136_row17_col0, #T_d4136_row18_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %%
departure_airport = 'AMS'
arrival_airport = 'LAX'
month = 'MAR'
year = '2024'

results_reader = ResultsReader(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_results(df)
# Out:
# <style type="text/css">
# #T_ae5a3 th.col-1 {
#   text-align: left;
# }
# #T_ae5a3 td.col-1 {
#   text-align: center;
# }
# #T_ae5a3_row0_col0, #T_ae5a3_row1_col0, #T_ae5a3_row2_col0, #T_ae5a3_row3_col0, #T_ae5a3_row4_col0, #T_ae5a3_row5_col0, #T_ae5a3_row6_col0, #T_ae5a3_row7_col0, #T_ae5a3_row8_col0, #T_ae5a3_row9_col0, #T_ae5a3_row10_col0, #T_ae5a3_row11_col0, #T_ae5a3_row12_col0, #T_ae5a3_row13_col0, #T_ae5a3_row14_col0, #T_ae5a3_row15_col0 {
#   text-align: left;
# }
# #T_ae5a3_row16_col0, #T_ae5a3_row17_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %% [markdown]
# **All Flights ICN, IAH, SIN, LAX**

# %%
results_reader = ResultsReader()
df = results_reader.read_all_results()
results_reader.style_results(df)
# Out:
# <style type="text/css">
# #T_d3776 th.col-1 {
#   text-align: left;
# }
# #T_d3776 td.col-1 {
#   text-align: center;
# }
# ...

# %%
df = df.drop(df[df['Flight Number'] == 'KL603'].index)

# %%
average_df = df[:-1].copy()
average_df['Flight Date'] = pd.to_datetime(average_df['Flight Date'], format = '%d %b %y')
average_df['Month'] = average_df['Flight Date'].dt.month
month_map = {1: 'JAN', 2: 'FEB', 3: 'MAR'}
average_df['Month'] = average_df['Month'].replace(month_map)


average_df = average_df.groupby(['Flight Number', 'Month'])[['%MAC ZFW']].mean()

average_df
# Out:
#                       %MAC ZFW
# Flight Number Month
# KL601         FEB    31.771967
#               JAN    30.965085
#               MAR    30.849368
# KL661         FEB    31.206599
#               JAN    31.509222
#               MAR    32.414911
# KL835         FEB    32.188253
#               JAN    33.022483
#               MAR    32.912773
# KL855         FEB    34.670433
#               JAN    33.138025
#               MAR    33.616947

# %%
analysis_df = df.copy()
analysis_df['Flight Date'] = pd.to_datetime(analysis_df['Flight Date'], format = '%d %b %y')
analysis_df['Month'] = analysis_df['Flight Date'].dt.month

# %%
analysis_df
# Out:
#     Flight Number Flight Date Aircraft Type Aircraft Registration   %MAC ZFW  \
# 0           KL661  2024-02-01           789                 PHBHL  31.679319
# 1           KL661  2024-02-02           789                 PHBHI  29.340032
# 2           KL661  2024-02-04           789                 PHBHA  31.513419
# 3           KL661  2024-02-06           789                 PHBHH  30.420129
# 4           KL661  2024-02-08           781                 PHBKH  32.162367
# ..            ...         ...           ...                   ...        ...
# 198         KL835  2024-03-26           77W                 PHBVR  30.348718
# 199         KL835  2024-03-27           77W                 PHBVC  26.907457
# 200         KL835  2024-03-28           77W                 PHBVB  35.495920
# 201         Total         NaT           NaN                   NaN        NaN
# 202       Average         NaT           NaN                   NaN  32.402463
#
# ...

# %%
# %run Classes.ipynb

# %%
data_extraction = DataExtraction()
data_extraction.extract_individual_flight_details()
data_extraction.extract_individual_load_locations()
data_extraction.extract_individual_piece_information()
data_extraction.extract_individual_pax_information()
data_extraction.extract_individual_buildup_information()
data_extraction.delete_incorrect_folders()
# Out:
# /var/folders/tc/_8w7cdmd2dvfv79kbrjbdgd40000gp/T/ipykernel_93392/3425873600.py:61: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   flight_details_data = pd.read_csv(self.df_flight_details, parse_dates=['LegDepartureDateUtc'], date_parser = self.custom_date_parser)
# /var/folders/tc/_8w7cdmd2dvfv79kbrjbdgd40000gp/T/ipykernel_93392/3425873600.py:120: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   piece_information_data = pd.read_csv(self.df_piece_information, parse_dates = ['BookingSegmentFlightDateLT'], date_parser = self.custom_date_parser, converters=converters)
# ...

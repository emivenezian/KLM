# %%
# %run Classes.ipynb

# %%
filter_model = FilterData()

# %% [markdown]
# **Run the model for a specific month**

# %%
# departure_airport = 'AMS'
# arrival_airport = 'LAX'
# month = 'MAR'
# year = '2024'

# filtered_flights = filter_model.per_month(departure_airport = departure_airport, arrival_airport = arrival_airport, 
#                                           month = month, year = year)

# for flight_dir in filtered_flights:
#     try:
#         piece_information_csv = os.path.join(flight_dir, 'PieceInformation.csv')
#         flight_information_csv = os.path.join(flight_dir, 'FlightInformation.csv')
#         load_locations_csv = os.path.join(flight_dir, 'LoadLocations.csv')
#         pax_information_csv = os.path.join(flight_dir, 'PaxInformation.csv')
#         buildup_information_csv = os.path.join(flight_dir, 'BuildUpInformation.csv')

#         project_setup = ProjectSetup()
#         cargo, aircraft, EP, plot, data_analysis = project_setup.setup_project(piece_information_csv, flight_information_csv, 
#                                                                 load_locations_csv, pax_information_csv, 
#                                                                 buildup_information_csv, arrival_airport, 
#                                                                 baseline = False, optimized_actual = True)
        
#         %run Optimized_Actual.ipynb


#     except Exception as e:
#         traceback.print_exc()
#         continue

# %% [markdown]
# **Run the model for a specific flight**

# %%
flight_number = 'KL0855'
departure_airport = 'AMS'
arrival_airport = 'ICN'
day = '21'
month = 'FEB'
year = '2024'
restricted_loadlocations = ['42L', '42R']

flight = filter_model.per_flight(flight_number = flight_number, departure_airport = departure_airport, arrival_airport = arrival_airport, day = day, month = month, year = year)

try:
    piece_information_csv = os.path.join(flight, 'PieceInformation.csv')
    flight_information_csv = os.path.join(flight, 'FlightInformation.csv')
    load_locations_csv = os.path.join(flight, 'LoadLocations.csv')
    pax_information_csv = os.path.join(flight, 'PaxInformation.csv')
    buildup_information_csv = os.path.join(flight, 'BuildUpInformation.csv')

    project_setup = ProjectSetup()
    cargo, aircraft, EP, plot, data_analysis = project_setup.setup_project(piece_information_csv, flight_information_csv, 
                                                            load_locations_csv, pax_information_csv, 
                                                            buildup_information_csv, arrival_airport, restricted_loadlocations,
                                                            baseline = False, optimized_actual = True)
    
    # %run Optimized_Actual.ipynb

except Exception as e:
    print(f"An error occurred while processing flight {flight_number}:")
    traceback.print_exc()
# Out:
# Running the model for Flight KL0855 AMSICN 21 FEB 2024
# ========================================================================================================
# The model will run the following flight:
# --------------------------------------------------------------------------------------------------------
# Flight Number: KL855 PHBQD - Aircraft Type: 772 - Departure: AMS - Arrival: ICN - Date: 21 FEB 24
#
# ZFW: 186113.6 kg - TOW: 266582.6 kg - LW: 191517.6 kg - OEW: 148459.0 kg
#
# Fuel: 80469 kg - Trip Fuel: 75065 kg
#
# Number of Cargo ULDs used: 3
#
# Number of BAX ULDs: 9 - Number of BUP ULDs: 0 - Number of T ULDs: 5
# --------------------------------------------------------------------------------------------------------
# ULD set available for loading:
# PAG-18, PAG
# PAG-20, PAG
# PAG-23, PAG
# --------------------------------------------------------------------------------------------------------
# BAX and BUP set for loading:
# BAX-0, AKE
# BAX-1, AKE
# BAX-3, AKE
# BAX-4, AKE
# BAX-6, AKE
# BAX-7, AKE
# BAX-8, AKE
# BAX-9, AKE
# BAX-11, AKE
# T-24, PMC
# T-25, PMC
# T-26, PMC
# T-27, PMC
# T-28, AKE
# --------------------------------------------------------------------------------------------------------
# PAX allocation:
# PAX-A: 28
# PAX-B: 32
# PAX-C: 115
# PAX-D: 53
# PAX-E: 72
# PAX-F: 0
# PAX-G: 0
# Total PAX: 300
# --------------------------------------------------------------------------------------------------------
# Check if all items fit the ULDs dimensions:
#
# 37 / 37 items fit the dimensions of the ULDs
# --------------------------------------------------------------------------------------------------------
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-30
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1265U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 21462 rows, 681 columns and 53145 nonzeros
# Model fingerprint: 0x408e8bfb
# Variable types: 1 continuous, 680 integer (680 binary)
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+03]
#   Objective range  [4e-01, 4e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+04]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 6 objectives (3 combined) ...
# ---------------------------------------------------------------------------
# Warning: Ignoring the last 3 of 6 multiobjective environments.
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 21344 rows and 310 columns
# Presolve time: 0.02s
# Presolved: 118 rows, 371 columns, 2017 nonzeros
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 () ...
# ---------------------------------------------------------------------------
#
# Presolve time: 0.02s
# Presolved: 118 rows, 371 columns, 2017 nonzeros
# Variable types: 1 continuous, 370 integer (370 binary)
#
# Root relaxation: objective -3.160064e+01, 161 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  -31.60064    0   35          -  -31.60064      -     -    0s
# H    0     0                     -29.4795525  -31.60064  7.20%     -    0s
# H    0     0                     -29.9541183  -31.60064  5.50%     -    0s
# H    0     0                     -29.9569621  -31.60064  5.49%     -    0s
# H    0     0                     -30.0349246  -31.60064  5.21%     -    0s
#      0     0  -30.91086    0   10  -30.03492  -30.91086  2.92%     -    0s
# H    0     0                     -30.6297467  -30.91086  0.92%     -    0s
# H    0     0                     -30.9108591  -30.91086  0.00%     -    0s
#      0     0  -30.91086    0   10  -30.91086  -30.91086  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   Clique: 8
#   Zero half: 9
#
# Explored 1 nodes (209 simplex iterations) in 0.07 seconds (0.03 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: -30.9109 -30.6297 -30.0349 ... -29.4796
# No other solutions better than -30.9109
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -3.091085914563e+01, best bound -3.091085914563e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 26
#
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 118 rows, 371 columns, 2017 nonzeros
# Variable types: 1 continuous, 370 integer (370 binary)
#
# Root relaxation: objective 1.849448e+01, 149 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   18.49448    0   28   26.00000   18.49448  28.9%     -    0s
#      0     0   24.98439    0   35   26.00000   24.98439  3.91%     -    0s
#      0     0   24.98439    0   35   26.00000   24.98439  3.91%     -    0s
#      0     0   24.98439    0   35   26.00000   24.98439  3.91%     -    0s
#      0     0   24.98439    0   35   26.00000   24.98439  3.91%     -    0s
# *    0     0               0      25.0000000   25.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 5
#   Clique: 3
#   MIR: 2
#   Zero half: 7
#
# Explored 1 nodes (260 simplex iterations) in 0.11 seconds (0.04 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 25 26
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.500000000000e+01, best bound 2.500000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 3 (weighted) ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 0
#
#
# Explored 0 nodes (0 simplex iterations) in 0.12 seconds (0.04 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.14 seconds (0.04 work units), solution count 7
#
# Solution found
# ULD PAG-20 with weight 835.0 kg is loaded to position 11P
# ULD PAG-18 with weight 415.0 kg is loaded to position 12P
# ULD T-28 with weight 145.0 kg is loaded to position 14L
# ULD BAX-6 with weight 356.0 kg is loaded to position 14R
# ULD T-24 with weight 1050.0 kg is loaded to position 21P
# ULD T-27 with weight 1000.0 kg is loaded to position 22P
# ULD T-26 with weight 1030.0 kg is loaded to position 23P
# ULD BAX-8 with weight 770.0 kg is loaded to position 31L
# ULD BAX-4 with weight 755.0 kg is loaded to position 31R
# ULD BAX-0 with weight 645.0 kg is loaded to position 32L
# ULD BAX-9 with weight 707.0 kg is loaded to position 32R
# ULD BAX-1 with weight 703.0 kg is loaded to position 33L
# ULD BAX-7 with weight 699.0 kg is loaded to position 33R
# ULD BAX-3 with weight 788.0 kg is loaded to position 41L
# ULD BAX-11 with weight 785.0 kg is loaded to position 41R
# ULD PAG-23 with weight 1105.0 kg is loaded to position 41P
# ULD T-25 with weight 1060.0 kg is loaded to position 42P
# ---------------------------------------------------------------------------
# Weight in Compartment 1: 1751.0 kg
# Weight in Compartment 2: 3080.0 kg
# Weight in Compartment 3: 4279.0 kg
# Weight in Compartment 4: 3738.0 kg
# ===========================================================================
# %MAC ZFW is 30.910859145628383
# ---------------------------------------------------------------------------
# The actual %MAC ZFW for this flight was 27.5
# Resulting in a fuel deviation of -0.196% or -146.784 kg
# ---------------------------------------------------------------------------
# 3 ULDs are built by the model
# 3 ULDs were actually built
# ---------------------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %run Classes.ipynb

# %%
filter_model = FilterData()

# %% [markdown]
# **Run the model for a specific month**

# %%
 departure_airport = 'AMS'
 arrival_airport = 'IAH'
 month = 'JAN'
 year = '2024'

 filtered_flights = filter_model.per_month(departure_airport = departure_airport, arrival_airport = arrival_airport, 
                                           month = month, year = year)

 for flight_dir in filtered_flights:
     try:
         piece_information_csv = os.path.join(flight_dir, 'PieceInformation.csv')
         flight_information_csv = os.path.join(flight_dir, 'FlightInformation.csv')
         load_locations_csv = os.path.join(flight_dir, 'LoadLocations.csv')
         pax_information_csv = os.path.join(flight_dir, 'PaxInformation.csv')
         buildup_information_csv = os.path.join(flight_dir, 'BuildUpInformation.csv')

         project_setup = ProjectSetup()
         cargo, aircraft, EP, plot, data_analysis = project_setup.setup_project(piece_information_csv, flight_information_csv, 
                                                                 load_locations_csv, pax_information_csv, 
                                                                 buildup_information_csv, arrival_airport,
                                                                                restricted_locations={},
                                                                 baseline = False, optimized_actual = False, BAX_fixed=True)
        
         # %run BAX_Fixed.ipynb


     except Exception as e:
         traceback.print_exc()
         continue
# Out:
# 4 flights found for AMS to IAH in Jan 2024
# ========================================================================================================
# The model will run the following flight:
# --------------------------------------------------------------------------------------------------------
# Flight Number: KL661 PHBHE - Aircraft Type: 789 - Departure: AMS - Arrival: IAH - Date: 23 JAN 24
#
# ZFW: 172547.6 kg - TOW: 242390.6 kg - LW: 179842.6 kg - OEW: 127707.0 kg
#
# Fuel: 69843 kg - Trip Fuel: 62548 kg
#
# Number of Cargo ULDs used: 4
#
# Number of BAX ULDs: 8 - Number of BUP ULDs: 0 - Number of T ULDs: 6
# --------------------------------------------------------------------------------------------------------
# ULD set available for loading:
# PMC-17, PMC
# PMC-20, PMC
# PMC-21, PMC
# PMC-22, PMC
# --------------------------------------------------------------------------------------------------------
# BAX and BUP set for loading:
# BAX-0, AKE
# BAX-2, AKE
# BAX-4, AKE
# BAX-5, AKE
# BAX-7, AKE
# BAX-10, AKE
# BAX-16, AKE
# BAX-24, AKE
# T-25, AKE
# T-26, AKE
# T-27, PMC
# T-28, PMC
# T-29, PMC
# T-30, PMC
# --------------------------------------------------------------------------------------------------------
# PAX allocation:
# PAX-A: 29
# PAX-B: 33
# PAX-C: 41
# PAX-D: 68
# PAX-E: 57
# PAX-F: 0
# PAX-G: 0
# Total PAX: 228
# --------------------------------------------------------------------------------------------------------
# Check if all items fit the ULDs dimensions:
#
# 190 / 190 items fit the dimensions of the ULDs
# --------------------------------------------------------------------------------------------------------
# Iteration 1
# ===========================================================================
# Starting optimization for iteration 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (mac64[arm] - Darwin 24.4.0 24E263)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1158147 rows, 326247 columns and 4429167 nonzeros
# Model fingerprint: 0x6dc573e2
# Variable types: 160753 continuous, 165494 integer (165494 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 1e+07]
#   Objective range  [5e-01, 4e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e-01, 5e+04]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 6 objectives...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve...
# ---------------------------------------------------------------------------
#
# Presolve removed 1120182 rows and 312720 columns
# Presolve time: 0.28s
# Presolved: 37965 rows, 13527 columns, 167079 nonzeros
#
# Multi-objectives: optimize objective 1 () ...
# ---------------------------------------------------------------------------
#
# Presolve removed 1293 rows and 482 columns
# Presolve time: 0.17s
# Presolved: 36672 rows, 13045 columns, 110948 nonzeros
# Variable types: 6081 continuous, 6964 integer (6964 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 36608 rows, 12981 columns, 110820 nonzeros
#
#
# Use crossover to convert LP symmetric solution to basic solution...
# Concurrent spin time: 0.02s
#
# Solved with dual simplex
#
# Root relaxation: objective -3.213845e+01, 1050 iterations, 0.12 seconds (0.18 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  -32.13845    0  391          -  -32.13845      -     -    3s
# H    0     0                     -29.0182282  -32.13845  10.8%     -    3s
# H    0     0                     -29.9611198  -32.13845  7.27%     -    3s
# H    0     0                     -31.1162204  -32.13845  3.29%     -    3s
# H    0     0                     -31.1179715  -32.13845  3.28%     -    3s
# H    0     0                     -31.2713860  -32.13845  2.77%     -    3s
# H    0     0                     -32.1271739  -32.13845  0.04%     -    3s
#      0     0  -32.13845    0  693  -32.12717  -32.13845  0.04%     -    6s
# H    0     0                     -32.1357311  -32.13845  0.01%     -    6s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 1
#   Implied bound: 2
#   Clique: 4
#   Flow cover: 1
#   Mod-K: 1
#   RLT: 81
#   Relax-and-lift: 28
#   BQP: 7
#
# Explored 1 nodes (17224 simplex iterations) in 6.39 seconds (12.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: -32.1357 -32.1272 -31.2714 ... -29.0182
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -3.213573112013e+01, best bound -3.213844863222e+01, gap 0.0085%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 6.23233e+07
#
# Presolve removed 1294 rows and 482 columns
# Presolve time: 0.17s
# Presolved: 36672 rows, 13045 columns, 110948 nonzeros
# Variable types: 6081 continuous, 6964 integer (6964 binary)
#
# Explored 0 nodes (0 simplex iterations) in 6.59 seconds (12.44 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 6.23233e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.232334800000e+07, best bound 6.232334800000e+07, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 3 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 18
#
# Presolve removed 1336 rows and 474 columns
# Presolve time: 0.34s
# Presolved: 36631 rows, 13053 columns, 116329 nonzeros
# Variable types: 6081 continuous, 6972 integer (6964 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 36563 rows, 12985 columns, 116193 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.5610132e+01   6.523418e+00   1.247569e+06      7s
#       73    1.5610132e+01   0.000000e+00   0.000000e+00      7s
#       73    1.5610132e+01   0.000000e+00   0.000000e+00      7s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#     1181 PPushes remaining with PInf 0.0000000e+00                 7s
#
# Solved with dual simplex
#
# Root relaxation: objective 1.561013e+01, 629 iterations, 0.09 seconds (0.14 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   15.61013    0  400   18.00000   15.61013  13.3%     -    9s
# H    0     0                      17.0000000   15.61013  8.18%     -    9s
#      0     0   15.61013    0  615   17.00000   15.61013  8.18%     -   13s
#      0     0   16.00000    0  223   17.00000   16.00000  5.88%     -   16s
# H    0     0                      16.0000000   16.00000  0.00%     -   17s
#      0     0   16.00000    0  223   16.00000   16.00000  0.00%     -   17s
#
# Cutting planes:
#   Implied bound: 747
#   MIR: 8
#   Flow cover: 4
#   Zero half: 59
#   RLT: 61
#
# Explored 1 nodes (46210 simplex iterations) in 17.06 seconds (28.77 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 16 17 18
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.600000000000e+01, best bound 1.600000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 4 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 2
#
# Presolve removed 1332 rows and 470 columns
# Presolve time: 0.34s
# Presolved: 36636 rows, 13057 columns, 116653 nonzeros
# Found heuristic solution: objective 0.4000000
# Variable types: 6085 continuous, 6972 integer (6964 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 36568 rows, 12989 columns, 116517 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   6.523418e+00   1.247569e+06     17s
#       73    0.0000000e+00   0.000000e+00   0.000000e+00     17s
#       73    0.0000000e+00   0.000000e+00   0.000000e+00     17s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#     1185 PPushes remaining with PInf 0.0000000e+00                17s
#        0 PPushes remaining with PInf 0.0000000e+00                18s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00     18s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1261    0.0000000e+00   0.000000e+00   0.000000e+00     18s
#     1261    0.0000000e+00   0.000000e+00   0.000000e+00     18s
#
# Solved with dual simplex
#
# Root relaxation: objective 0.000000e+00, 704 iterations, 0.09 seconds (0.11 work units)
# Total elapsed time = 20.62s (DegenMoves)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  621    0.40000    0.00000   100%     -   25s
#      0     0     cutoff    0         0.40000    0.40000  0.00%     -   28s
#
# Cutting planes:
#   Implied bound: 2118
#   Zero half: 1
#   RLT: 713
#
# Explored 1 nodes (31357 simplex iterations) in 28.23 seconds (53.38 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 0.4 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.000000000000e-01, best bound 4.000000000000e-01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 5 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 104
#
# Presolve removed 1268 rows and 406 columns
# Presolve time: 0.31s
# Presolved: 36701 rows, 13121 columns, 116997 nonzeros
# Found heuristic solution: objective 74.0000000
# Variable types: 6085 continuous, 7036 integer (7028 binary)
# Found heuristic solution: objective 31.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 36569 rows, 12989 columns, 116521 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6000000e+01   6.523418e+00   1.247569e+06     29s
#       73    2.6000000e+01   0.000000e+00   0.000000e+00     29s
#       73    2.6000000e+01   0.000000e+00   0.000000e+00     29s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#     1188 PPushes remaining with PInf 0.0000000e+00                29s
#        0 PPushes remaining with PInf 0.0000000e+00                29s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 6.8696405e-16     29s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1264    2.6000000e+01   0.000000e+00   0.000000e+00     29s
#     1264    2.6000000e+01   0.000000e+00   0.000000e+00     29s
#
# Solved with dual simplex
#
# Root relaxation: objective 2.600000e+01, 715 iterations, 0.09 seconds (0.11 work units)
# Total elapsed time = 30.69s (DegenMoves)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   26.00000    0  288   31.00000   26.00000  16.1%     -   31s
# H    0     0                      26.0000000   26.00000  0.00%     -   32s
#      0     0   26.00000    0  393   26.00000   26.00000  0.00%     -   32s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 10
#   Implied bound: 342
#   Clique: 183
#   MIR: 2
#   Flow cover: 2
#   Zero half: 1
#   RLT: 56
#   Relax-and-lift: 12
#   BQP: 102
#
# Explored 1 nodes (31228 simplex iterations) in 32.54 seconds (64.38 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 26 31 74 104
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.600000000000e+01, best bound 2.600000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 6 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 10
#
#
# Explored 0 nodes (0 simplex iterations) in 32.56 seconds (64.38 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 10
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+01, best bound 1.000000000000e+01, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 32.66 seconds (64.38 work units), solution count 10
#
# Solution found
# ULD BAX-16 with weight 828.0 kg is loaded to position 11L
# ULD BAX-10 with weight 758.0 kg is loaded to position 11R
# ULD BAX-5 with weight 720.0 kg is loaded to position 12L
# ULD BAX-7 with weight 543.0 kg is loaded to position 12R
# ULD BAX-24 with weight 161.0 kg is loaded to position 13L
# ULD BAX-0 with weight 665.0 kg is loaded to position 13R
# ULD BAX-4 with weight 776.0 kg is loaded to position 14L
# ULD BAX-2 with weight 690.0 kg is loaded to position 14R
# ULD T-25 with weight 476 kg is loaded to position 15L
# ULD T-26 with weight 466 kg is loaded to position 21L
# ULD PMC-17 with weight 2323.2 kg with a volume loadfactor of 79.856% and a weight loadfactor of 45.535% is loaded to position 22P
# ULD T-29 with weight 4335 kg is loaded to position 31P
# ULD T-30 with weight 3740 kg is loaded to position 32P
# ULD T-28 with weight 4330 kg is loaded to position 33P
# ULD T-27 with weight 2915 kg is loaded to position 41P
# ULD PMC-22 with weight 1962.4 kg with a volume loadfactor of 48.955% and a weight loadfactor of 38.463% is loaded to position 42P
# ---------------------------------------------------------------------------
# Weight in Compartment 1: 5617.0 kg
# Weight in Compartment 2: 2789.2 kg
# Weight in Compartment 3: 12405.0 kg
# Weight in Compartment 4: 4877.4 kg
# ===========================================================================
# %MAC ZFW is 32.136306877315754
# ---------------------------------------------------------------------------
# The actual %MAC ZFW for this flight was 31.7
# Resulting in a fuel deviation of -0.036% or -22.599 kg
# ---------------------------------------------------------------------------
# 2 ULDs are built by the model
# 4 ULDs were actually built
# ---------------------------------------------------------------------------
# The ULDs are builded and blocked in the model:
# ---------------------------------------------------------------------------
# Items deferred for ULD PMC-22:
# 64074780-11 deferred due to item does not fit in ULD
# ---------------------------------------------------------------------------
# Flag set: opening a new ULD
# Item 64074780-11 is causing the flag
# ---------------------------------------------------------------------------
# 1 items have been deferred this iteration
# 1 ULDs have deferred items this iteration
# Iteration 2
# ===========================================================================
# Starting optimization for iteration 2
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (mac64[arm] - Darwin 24.4.0 24E263)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1158147 rows, 326247 columns and 4429167 nonzeros
# Model fingerprint: 0xe6d4c9b4
# Variable types: 160753 continuous, 165494 integer (165494 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 1e+07]
#   Objective range  [5e-01, 4e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e-01, 5e+04]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 6 objectives...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve...
# ---------------------------------------------------------------------------
#
# Presolve removed 1149219 rows and 322116 columns
# Presolve time: 0.24s
# Presolved: 8928 rows, 4131 columns, 42463 nonzeros
#
# Multi-objectives: optimize objective 1 () ...
# ---------------------------------------------------------------------------
#
# Presolve removed 6724 rows and 3260 columns
# Presolve time: 0.02s
# Presolved: 2204 rows, 871 columns, 7236 nonzeros
# Variable types: 353 continuous, 518 integer (518 binary)
#
# Root relaxation: objective -3.213845e+01, 183 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  -32.13845    0    6          -  -32.13845      -     -    0s
# H    0     0                     -20.0721469  -32.13845  60.1%     -    0s
# H    0     0                     -30.1750054  -32.13845  6.51%     -    0s
# H    0     0                     -31.6317552  -32.13845  1.60%     -    0s
# H    0     0                     -32.0381039  -32.13845  0.31%     -    0s
# H    0     0                     -32.0909232  -32.13845  0.15%     -    0s
# H    0     0                     -32.0938338  -32.13845  0.14%     -    0s
# H    0     0                     -32.1357049  -32.13845  0.01%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 1
#   GUB cover: 2
#   RLT: 1
#
# Explored 1 nodes (183 simplex iterations) in 0.39 seconds (0.98 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: -32.1357 -32.0938 -32.0909 ... -20.0721
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -3.213570494232e+01, best bound -3.213844863222e+01, gap 0.0085%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 6.23233e+07
#
# Presolve removed 6725 rows and 3260 columns
# Presolve time: 0.02s
# Presolved: 2204 rows, 871 columns, 7236 nonzeros
# Variable types: 353 continuous, 518 integer (518 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.41 seconds (1.03 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 6.23233e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.232334800000e+07, best bound 6.232334800000e+07, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 3 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 17
#
# Presolve removed 6766 rows and 3257 columns
# Presolve time: 0.03s
# Presolved: 2164 rows, 874 columns, 8274 nonzeros
# Variable types: 353 continuous, 521 integer (518 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.45 seconds (1.10 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 17
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.700000000000e+01, best bound 1.700000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 4 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 2
#
# Presolve removed 6764 rows and 3254 columns
# Presolve time: 0.03s
# Presolved: 2167 rows, 877 columns, 8321 nonzeros
# Found heuristic solution: objective 0.4000000
# Variable types: 356 continuous, 521 integer (518 binary)
#
# Root relaxation: objective 1.104550e-01, 289 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.11045    0   53    0.40000    0.11045  72.4%     -    0s
# H    0     0                       0.2171306    0.11045  49.1%     -    0s
# H    0     0                       0.2000000    0.11045  44.8%     -    0s
#      0     0 infeasible    0         0.20000    0.20000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 4
#   Implied bound: 20
#   Clique: 7
#   MIR: 1
#   GUB cover: 1
#   Zero half: 1
#   RLT: 3
#   Relax-and-lift: 7
#
# Explored 1 nodes (1283 simplex iterations) in 0.53 seconds (1.25 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 0.2 0.217131 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e-01, best bound 2.000000000000e-01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 5 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 36
#
# Presolve removed 6761 rows and 3251 columns
# Presolve time: 0.03s
# Presolved: 2171 rows, 880 columns, 8359 nonzeros
# Found heuristic solution: objective 28.0000000
# Variable types: 356 continuous, 524 integer (521 binary)
# Found heuristic solution: objective 27.0000000
#
# Root relaxation: objective 2.600000e+01, 347 iterations, 0.01 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 infeasible    0        27.00000   27.00000  0.00%     -    0s
#
# Explored 1 nodes (2006 simplex iterations) in 0.60 seconds (1.39 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 27 28 36
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.700000000000e+01, best bound 2.700000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 6 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 10
#
#
# Explored 0 nodes (0 simplex iterations) in 0.61 seconds (1.39 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 10
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+01, best bound 1.000000000000e+01, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.68 seconds (1.39 work units), solution count 10
#
# Solution found
# ULD BAX-16 with weight 828.0 kg is loaded to position 11L
# ULD BAX-10 with weight 758.0 kg is loaded to position 11R
# ULD BAX-5 with weight 720.0 kg is loaded to position 12L
# ULD BAX-7 with weight 543.0 kg is loaded to position 12R
# ULD BAX-24 with weight 161.0 kg is loaded to position 13L
# ULD BAX-0 with weight 665.0 kg is loaded to position 13R
# ULD BAX-4 with weight 776.0 kg is loaded to position 14L
# ULD BAX-2 with weight 690.0 kg is loaded to position 14R
# ULD T-26 with weight 466 kg is loaded to position 15L
# ULD T-25 with weight 476 kg is loaded to position 15R
# ULD PMC-21 with weight 593.8 kg with a volume loadfactor of 22.031% and a weight loadfactor of 11.638% is loaded to position 21P
# ULD PMC-17 with weight 2323.2 kg with a volume loadfactor of 79.856% and a weight loadfactor of 45.535% is loaded to position 23P
# ULD T-30 with weight 3740 kg is loaded to position 31P
# ULD PMC-20 with weight 1368.6 kg with a volume loadfactor of 26.924% and a weight loadfactor of 26.825% is loaded to position 32P
# ULD T-29 with weight 4335 kg is loaded to position 33P
# ULD T-27 with weight 2915 kg is loaded to position 41P
# ULD T-28 with weight 4330 kg is loaded to position 42P
# ---------------------------------------------------------------------------
# Weight in Compartment 1: 6083.0 kg
# Weight in Compartment 2: 2917.0 kg
# Weight in Compartment 3: 9443.6 kg
# Weight in Compartment 4: 7245.0 kg
# ===========================================================================
# %MAC ZFW is 32.13570494231538
# ---------------------------------------------------------------------------
# The actual %MAC ZFW for this flight was 31.7
# Resulting in a fuel deviation of -0.036% or -22.561 kg
# ---------------------------------------------------------------------------
# 3 ULDs are built by the model
# 4 ULDs were actually built
# ---------------------------------------------------------------------------
# The ULDs are builded and blocked in the model:
# PMC-17
# ---------------------------------------------------------------------------
# Optimal solution found with no deferred items
# ===========================================================================
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# The model will run the following flight:
# --------------------------------------------------------------------------------------------------------
# Flight Number: KL661 PHBHG - Aircraft Type: 789 - Departure: AMS - Arrival: IAH - Date: 07 JAN 24
#
# ZFW: 169323.2 kg - TOW: 231308.2 kg - LW: 176166.2 kg - OEW: 128129.0 kg
#
# Fuel: 61985 kg - Trip Fuel: 55142 kg
#
# Number of Cargo ULDs used: 6
#
# Number of BAX ULDs: 9 - Number of BUP ULDs: 0 - Number of T ULDs: 2
# --------------------------------------------------------------------------------------------------------
# ULD set available for loading:
# PMC-21, PMC
# PMC-22, PMC
# PMC-23, PMC
# PMC-24, PMC
# PMC-25, PMC
# PMC-27, PMC
# --------------------------------------------------------------------------------------------------------
# BAX and BUP set for loading:
# BAX-0, AKE
# BAX-3, AKE
# BAX-5, AKE
# BAX-7, AKE
# BAX-8, AKE
# BAX-9, AKE
# BAX-16, AKE
# BAX-18, AKE
# BAX-28, AKE
# T-29, PAG
# T-30, PMC
# --------------------------------------------------------------------------------------------------------
# PAX allocation:
# PAX-A: 30
# PAX-B: 39
# PAX-C: 72
# PAX-D: 71
# PAX-E: 62
# PAX-F: 0
# PAX-G: 0
# Total PAX: 274
# --------------------------------------------------------------------------------------------------------
# Check if all items fit the ULDs dimensions:
#
# 132 / 132 items fit the dimensions of the ULDs
# --------------------------------------------------------------------------------------------------------
# Iteration 1
# ===========================================================================
# Starting optimization for iteration 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (mac64[arm] - Darwin 24.4.0 24E263)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 767080 rows, 214850 columns and 2922655 nonzeros
# Model fingerprint: 0x2f28e3c6
# Variable types: 105487 continuous, 109363 integer (109363 binary)
# Coefficient statistics:
#   Matrix range     [7e-04, 1e+07]
#   Objective range  [5e-01, 4e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e-01, 5e+04]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 6 objectives...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve...
# ---------------------------------------------------------------------------
#
# Presolve removed 728571 rows and 200468 columns
# Presolve time: 0.19s
# Presolved: 38509 rows, 14382 columns, 145379 nonzeros
#
# Multi-objectives: optimize objective 1 () ...
# ---------------------------------------------------------------------------
#
# Presolve removed 409 rows and 847 columns
# Presolve time: 0.15s
# Presolved: 38100 rows, 13535 columns, 115649 nonzeros
# Variable types: 6337 continuous, 7198 integer (7198 binary)
# Found heuristic solution: objective -28.8965643
# Found heuristic solution: objective -29.3155306
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 38052 rows, 13487 columns, 115553 nonzeros
#
#
# Use crossover to convert LP symmetric solution to basic solution...
# Concurrent spin time: 0.02s
#
# Solved with primal simplex
#
# Root relaxation: objective -3.200653e+01, 710 iterations, 0.10 seconds (0.14 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  -32.00653    0  280  -29.31553  -32.00653  9.18%     -    3s
# H    0     0                     -31.6828926  -32.00653  1.02%     -    3s
# H    0     0                     -32.0049781  -32.00653  0.00%     -    3s
#
# Explored 1 nodes (9512 simplex iterations) in 3.14 seconds (5.31 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: -32.005 -31.6829 -29.3155 -28.8966
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -3.200497813698e+01, best bound -3.200653197214e+01, gap 0.0049%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 3.13087e+07
#
# Presolve removed 410 rows and 847 columns
# Presolve time: 0.14s
# Presolved: 38100 rows, 13535 columns, 115649 nonzeros
# Variable types: 6337 continuous, 7198 integer (7198 binary)
#
# Explored 0 nodes (0 simplex iterations) in 3.30 seconds (5.65 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 3.13087e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.130867400000e+07, best bound 3.130867400000e+07, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 3 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 15
#
# Presolve removed 406 rows and 841 columns
# Presolve time: 0.23s
# Presolved: 38105 rows, 13541 columns, 122668 nonzeros
# Variable types: 6337 continuous, 7204 integer (7198 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 38057 rows, 13493 columns, 122572 nonzeros
#
#
# Solved with primal simplex
#
# Root relaxation: cutoff, 2811 iterations, 2.51 seconds (0.23 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0        15.00000   15.00000  0.00%     -    6s
#
# Explored 1 nodes (2811 simplex iterations) in 6.06 seconds (6.38 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 15
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.500000000000e+01, best bound 1.500000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 4 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 2
#
# Presolve removed 400 rows and 835 columns
# Presolve time: 0.23s
# Presolved: 38112 rows, 13547 columns, 123472 nonzeros
# Found heuristic solution: objective 0.4000000
# Variable types: 6343 continuous, 7204 integer (7198 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 38064 rows, 13499 columns, 123376 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.795267e+03   4.499267e+08      6s
#     1172    0.0000000e+00   0.000000e+00   0.000000e+00      6s
#     1172    0.0000000e+00   0.000000e+00   0.000000e+00      6s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#     1002 PPushes remaining with PInf 0.0000000e+00                 6s
#        0 PPushes remaining with PInf 0.0000000e+00                 6s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      6s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2177    0.0000000e+00   0.000000e+00   0.000000e+00      6s
#     2177    0.0000000e+00   0.000000e+00   0.000000e+00      6s
#
# Solved with dual simplex
#
# Root relaxation: objective 0.000000e+00, 2543 iterations, 0.13 seconds (0.19 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  293    0.40000    0.00000   100%     -   11s
#      0     0    0.00000    0  693    0.40000    0.00000   100%     -   16s
#      0     0    0.00000    0  705    0.40000    0.00000   100%     -   17s
#      0     0     cutoff    0         0.40000    0.40000  0.00%     -   19s
#
# Cutting planes:
#   Gomory: 3
#   Lift-and-project: 2
#   Cover: 1
#   Implied bound: 592
#   MIR: 3
#   Zero half: 39
#   RLT: 320
#   Relax-and-lift: 2
#   BQP: 28
#
# Explored 1 nodes (44221 simplex iterations) in 19.04 seconds (26.66 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 0.4 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.000000000000e-01, best bound 4.000000000000e-01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 5 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 294
#
# Presolve removed 244 rows and 679 columns
# Presolve time: 0.24s
# Presolved: 38269 rows, 13703 columns, 124288 nonzeros
# Found heuristic solution: objective 179.0000000
# Variable types: 6343 continuous, 7360 integer (7354 binary)
# Found heuristic solution: objective 86.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 38065 rows, 13499 columns, 123382 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.9073654e+01   2.795367e+03   4.516455e+08     19s
#      937    4.9000000e+01   0.000000e+00   0.000000e+00     19s
#      937    4.9000000e+01   0.000000e+00   0.000000e+00     19s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#      754 PPushes remaining with PInf 0.0000000e+00                19s
#        0 PPushes remaining with PInf 0.0000000e+00                19s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00     19s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1694    4.9000000e+01   0.000000e+00   0.000000e+00     19s
#     1694    4.9000000e+01   0.000000e+00   0.000000e+00     19s
#
# Solved with primal simplex
#
# Root relaxation: objective 4.900000e+01, 1694 iterations, 0.10 seconds (0.15 work units)
# Total elapsed time = 20.15s (DegenMoves)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   49.00000    0  378   86.00000   49.00000  43.0%     -   22s
# H    0     0                      65.0000000   49.00000  24.6%     -   24s
#      0     0   49.00000    0  669   65.00000   49.00000  24.6%     -   25s
# H    0     0                      54.0000000   49.00000  9.26%     -   25s
# H    0     0                      53.0000000   49.00000  7.55%     -   26s
# H    0     0                      50.0000000   49.00000  2.00%     -   26s
#      0     0   49.00000    0  614   50.00000   49.00000  2.00%     -   26s
# H    0     0                      49.0000000   49.00000  0.00%     -   28s
#      0     0   49.00000    0   84   49.00000   49.00000  0.00%     -   29s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 4
#   Lift-and-project: 1
#   Cover: 59
#   Implied bound: 776
#   Clique: 184
#   MIR: 11
#   Flow cover: 2
#   Zero half: 38
#   RLT: 512
#   Relax-and-lift: 33
#   BQP: 85
#   PSD: 5
#
# Explored 1 nodes (40069 simplex iterations) in 29.47 seconds (42.10 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 49 50 53 ... 294
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.900000000000e+01, best bound 4.900000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 6 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 13
#
#
# Explored 0 nodes (0 simplex iterations) in 29.48 seconds (42.10 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 13
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.300000000000e+01, best bound 1.300000000000e+01, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 29.54 seconds (42.10 work units), solution count 10
#
# Solution found
# ULD T-30 with weight 1345 kg is loaded to position 11P
# ULD PMC-25 with weight 1775.2 kg with a volume loadfactor of 79.319% and a weight loadfactor of 34.794% is loaded to position 12P
# ULD PMC-27 with weight 1308.3 kg with a volume loadfactor of 49.108% and a weight loadfactor of 25.643% is loaded to position 21P
# ULD T-29 with weight 2010 kg is loaded to position 22P
# ULD PMC-23 with weight 1834.4 kg with a volume loadfactor of 59.116% and a weight loadfactor of 35.954% is loaded to position 31P
# ULD PMC-22 with weight 3555.3 kg with a volume loadfactor of 73.587% and a weight loadfactor of 69.684% is loaded to position 32P
# ULD BAX-16 with weight 839.0 kg is loaded to position 34L
# ULD BAX-3 with weight 782.0 kg is loaded to position 34R
# ULD BAX-5 with weight 733.0 kg is loaded to position 41L
# ULD BAX-18 with weight 735.0 kg is loaded to position 41R
# ULD BAX-28 with weight 394.0 kg is loaded to position 42L
# ULD BAX-0 with weight 514.0 kg is loaded to position 43L
# ULD BAX-9 with weight 745.0 kg is loaded to position 43R
# ULD BAX-7 with weight 787.0 kg is loaded to position 44L
# ULD BAX-8 with weight 821.0 kg is loaded to position 44R
# ---------------------------------------------------------------------------
# Weight in Compartment 1: 3120.2 kg
# Weight in Compartment 2: 3318.3 kg
# Weight in Compartment 3: 7010.7 kg
# Weight in Compartment 4: 4729.0 kg
# ===========================================================================
# %MAC ZFW is 32.00569078780873
# ---------------------------------------------------------------------------
# The actual %MAC ZFW for this flight was 25.7
# Resulting in a fuel deviation of -0.546% or -300.838 kg
# ---------------------------------------------------------------------------
# 4 ULDs are built by the model
# 6 ULDs were actually built
# ---------------------------------------------------------------------------
# The ULDs are builded and blocked in the model:
# ---------------------------------------------------------------------------
# Items deferred for ULD PMC-22:
# 45823923 deferred due to item does not fit in ULD
# 62835301-1 deferred due to item does not fit in ULD
# 62835301-2 deferred due to item does not fit in ULD
# 62884754-1 deferred due to item does not fit in ULD
# 62884754-2 deferred due to item does not fit in ULD
# 63009796 deferred due to item does not fit in ULD
# 63720462-2 deferred due to item does not fit in ULD
# ---------------------------------------------------------------------------
# Items deferred for ULD PMC-25:
# 63347196-2 deferred due to item does not fit in ULD
# 63347196-3 deferred due to item does not fit in ULD
# 63347196-4 deferred due to item does not fit in ULD
# 63647253-2 deferred due to item does not fit in ULD
# ---------------------------------------------------------------------------
# 11 items have been deferred this iteration
# 2 ULDs have deferred items this iteration
# Continuing with optimal strategy due to high number of deferred items
# ===========================================================================
# Iteration 2
# ===========================================================================
# Starting optimization for iteration 2
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (mac64[arm] - Darwin 24.4.0 24E263)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 767080 rows, 214850 columns and 2922655 nonzeros
# Model fingerprint: 0x805c90ad
# Variable types: 105487 continuous, 109363 integer (109363 binary)
# Coefficient statistics:
#   Matrix range     [7e-04, 1e+07]
#   Objective range  [5e-01, 4e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e-01, 5e+04]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 6 objectives...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve...
# ---------------------------------------------------------------------------
#
# Presolve removed 729102 rows and 200655 columns
# Presolve time: 0.17s
# Presolved: 37978 rows, 14195 columns, 143375 nonzeros
#
# Multi-objectives: optimize objective 1 () ...
# ---------------------------------------------------------------------------
#
# Presolve removed 405 rows and 847 columns
# Presolve time: 0.16s
# Presolved: 37573 rows, 13348 columns, 114049 nonzeros
# Variable types: 6249 continuous, 7099 integer (7099 binary)
# Found heuristic solution: objective -29.0832560
# Found heuristic solution: objective -29.2504435
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 37525 rows, 13300 columns, 113953 nonzeros
#
#
# Use crossover to convert LP symmetric solution to basic solution...
# Concurrent spin time: 0.05s
#
# Solved with dual simplex
#
# Root relaxation: objective -3.200653e+01, 1390 iterations, 0.11 seconds (0.20 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  -32.00653    0  248  -29.25044  -32.00653  9.42%     -    3s
# H    0     0                     -30.0720013  -32.00653  6.43%     -    3s
# H    0     0                     -30.0801317  -32.00653  6.40%     -    3s
# H    0     0                     -30.1790789  -32.00653  6.06%     -    3s
# H    0     0                     -30.1815260  -32.00653  6.05%     -    3s
# H    0     0                     -31.8018258  -32.00653  0.64%     -    4s
# H    0     0                     -31.8241568  -32.00653  0.57%     -    4s
# H    0     0                     -32.0046486  -32.00653  0.01%     -    4s
#      0     0  -32.00653    0  440  -32.00465  -32.00653  0.01%     -    4s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 2
#   Implied bound: 253
#   Clique: 10
#   MIR: 3
#   StrongCG: 1
#   Zero half: 3
#   RLT: 386
#   Relax-and-lift: 41
#   BQP: 1199
#
# Explored 1 nodes (19856 simplex iterations) in 4.66 seconds (9.91 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 9: -32.0046 -31.8242 -31.8018 ... -29.0833
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -3.200464863563e+01, best bound -3.200653197214e+01, gap 0.0059%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 3.13087e+07
#
# Presolve removed 406 rows and 847 columns
# Presolve time: 0.15s
# Presolved: 37573 rows, 13348 columns, 114049 nonzeros
# Variable types: 6249 continuous, 7099 integer (7099 binary)
#
# Explored 0 nodes (0 simplex iterations) in 4.83 seconds (10.32 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 3.13087e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.130867400000e+07, best bound 3.130867400000e+07, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 3 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 16
#
# Presolve removed 402 rows and 841 columns
# Presolve time: 0.23s
# Presolved: 37578 rows, 13354 columns, 120977 nonzeros
# Variable types: 6249 continuous, 7105 integer (7099 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 37529 rows, 13305 columns, 120879 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.7000000e+01   2.079541e+02   5.915241e+07      5s
#      885    1.5000000e+01   0.000000e+00   0.000000e+00      5s
#      885    1.5000000e+01   0.000000e+00   0.000000e+00      5s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#      705 PPushes remaining with PInf 0.0000000e+00                 5s
#        0 PPushes remaining with PInf 0.0000000e+00                 5s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      5s
#
#
# Solved with dual simplex
#
# Root relaxation: objective 1.500000e+01, 1243 iterations, 0.08 seconds (0.15 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   15.00000    0   83   16.00000   15.00000  6.25%     -    6s
# H    0     0                      15.0000000   15.00000  0.00%     -    6s
#      0     0   15.00000    0   83   15.00000   15.00000  0.00%     -    6s
#
# Explored 1 nodes (7699 simplex iterations) in 6.22 seconds (13.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 15 16
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.500000000000e+01, best bound 1.500000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 4 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 2
#
# Presolve removed 397 rows and 835 columns
# Presolve time: 0.25s
# Presolved: 37584 rows, 13360 columns, 121764 nonzeros
# Found heuristic solution: objective 0.4000000
# Variable types: 6255 continuous, 7105 integer (7099 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 37535 rows, 13311 columns, 121666 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   7.028263e+02   1.436657e+08      7s
#     1091    0.0000000e+00   0.000000e+00   0.000000e+00      7s
#     1091    0.0000000e+00   0.000000e+00   0.000000e+00      7s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#      721 PPushes remaining with PInf 0.0000000e+00                 7s
#        0 PPushes remaining with PInf 0.0000000e+00                 7s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      7s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1815    0.0000000e+00   0.000000e+00   0.000000e+00      7s
#     1815    0.0000000e+00   0.000000e+00   0.000000e+00      7s
#
# Solved with primal simplex
#
# Root relaxation: objective 0.000000e+00, 1815 iterations, 0.11 seconds (0.21 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  338    0.40000    0.00000   100%     -    9s
#      0     0    0.00000    0 1450    0.40000    0.00000   100%     -   19s
#      0     0    0.00000    0 1378    0.40000    0.00000   100%     -   20s
#      0     0          -    0         0.40000    0.00000   100%     -   21s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 1
#   Implied bound: 657
#   MIR: 7
#   Zero half: 51
#   RLT: 190
#   Relax-and-lift: 3
#   BQP: 35
#
# ...
# H    0     0                     -32.0052878  -32.00653  0.00%     -    0s
# H    0     0                     -32.0058525  -32.00653  0.00%     -    0s
# H    0     0                     -32.0061331  -32.00653  0.00%     -    0s
# H    0     0                     -32.0061464  -32.00653  0.00%     -    0s
#
# Explored 1 nodes (1881 simplex iterations) in 0.58 seconds (1.18 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: -32.0061 -32.0061 -32.0059 ... -30.6193
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -3.200614635889e+01, best bound -3.200653197214e+01, gap 0.0012%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 3.13087e+07
#
# Presolve removed 2083 rows and 1741 columns
# Presolve time: 0.07s
# Presolved: 17753 rows, 6343 columns, 53960 nonzeros
# Variable types: 2953 continuous, 3390 integer (3390 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.65 seconds (1.38 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 3.13087e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.130867400000e+07, best bound 3.130867400000e+07, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 3 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 17
#
# Presolve removed 2090 rows and 1736 columns
# Presolve time: 0.11s
# Presolved: 17747 rows, 6348 columns, 57367 nonzeros
# Variable types: 2953 continuous, 3395 integer (3390 binary)
#
# Root relaxation: objective 1.500000e+01, 1524 iterations, 0.09 seconds (0.30 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   15.00000    0   96   17.00000   15.00000  11.8%     -    1s
# H    0     0                      15.0000000   15.00000  0.00%     -    1s
#
# Cutting planes:
#   Gomory: 4
#   Implied bound: 271
#   MIR: 6
#   Flow cover: 3
#   Zero half: 33
#   RLT: 187
#   BQP: 192
#
# Explored 1 nodes (7763 simplex iterations) in 1.80 seconds (3.41 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 15 17
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.500000000000e+01, best bound 1.500000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 4 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 2
#
# Presolve removed 2086 rows and 1731 columns
# Presolve time: 0.11s
# Presolved: 17752 rows, 6353 columns, 57741 nonzeros
# Found heuristic solution: objective 0.4000000
# Variable types: 2958 continuous, 3395 integer (3390 binary)
#
# Root relaxation: objective 0.000000e+00, 2718 iterations, 0.13 seconds (0.41 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0   99    0.40000    0.00000   100%     -    2s
#      0     0    0.25000    0  328    0.40000    0.25000  37.5%     -    4s
#
# Cutting planes:
#   Cover: 1
#   Implied bound: 113
#   MIR: 1
#   Zero half: 1
#   RLT: 48
#   Relax-and-lift: 20
#   BQP: 12
#
# Explored 1 nodes (14821 simplex iterations) in 4.10 seconds (7.86 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 0.4 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.000000000000e-01, best bound 4.000000000000e-01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 5 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 178
#
# Presolve removed 2008 rows and 1653 columns
# Presolve time: 0.11s
# Presolved: 17831 rows, 6431 columns, 58110 nonzeros
# Found heuristic solution: objective 112.0000000
# Variable types: 2958 continuous, 3473 integer (3468 binary)
# Found heuristic solution: objective 63.0000000
#
# Root relaxation: objective 5.000000e+01, 3765 iterations, 0.14 seconds (0.33 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   50.00000    0   45   63.00000   50.00000  20.6%     -    4s
# H    0     0                      53.0000000   50.00000  5.66%     -    4s
# H    0     0                      52.0000000   50.00000  3.85%     -    4s
# H    0     0                      51.0000000   50.00000  1.96%     -    4s
# H    0     0                      50.0000000   50.00000  0.00%     -    4s
#      0     0   50.00000    0   45   50.00000   50.00000  0.00%     -    4s
#
# Explored 1 nodes (8989 simplex iterations) in 4.80 seconds (9.36 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 50 51 52 ... 178
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.000000000000e+01, best bound 5.000000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 6 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 13
#
#
# Explored 0 nodes (0 simplex iterations) in 4.80 seconds (9.36 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 13
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.300000000000e+01, best bound 1.300000000000e+01, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 4.85 seconds (9.36 work units), solution count 10
#
# Solution found
# ULD PMC-27 with weight 924.5 kg with a volume loadfactor of 46.108% and a weight loadfactor of 18.120% is loaded to position 13P
# ULD PMC-22 with weight 2001.0 kg with a volume loadfactor of 69.865% and a weight loadfactor of 39.220% is loaded to position 21P
# ULD T-29 with weight 2010 kg is loaded to position 22P
# ULD PMC-24 with weight 2415.2 kg with a volume loadfactor of 72.347% and a weight loadfactor of 47.339% is loaded to position 23P
# ULD T-30 with weight 1345 kg is loaded to position 31P
# ULD PMC-21 with weight 3132.4 kg with a volume loadfactor of 72.811% and a weight loadfactor of 61.396% is loaded to position 32P
# ULD BAX-16 with weight 839.0 kg is loaded to position 34L
# ULD BAX-3 with weight 782.0 kg is loaded to position 34R
# ULD BAX-5 with weight 733.0 kg is loaded to position 41L
# ULD BAX-18 with weight 735.0 kg is loaded to position 41R
# ULD BAX-28 with weight 394.0 kg is loaded to position 42L
# ULD BAX-0 with weight 514.0 kg is loaded to position 43L
# ULD BAX-9 with weight 745.0 kg is loaded to position 43R
# ULD BAX-7 with weight 787.0 kg is loaded to position 44L
# ULD BAX-8 with weight 821.0 kg is loaded to position 44R
# ---------------------------------------------------------------------------
# Weight in Compartment 1: 924.5 kg
# Weight in Compartment 2: 6426.2 kg
# Weight in Compartment 3: 6098.4 kg
# Weight in Compartment 4: 4729.0 kg
# ===========================================================================
# %MAC ZFW is 32.00599816074939
# ---------------------------------------------------------------------------
# The actual %MAC ZFW for this flight was 25.7
# Resulting in a fuel deviation of -0.546% or -300.855 kg
# ---------------------------------------------------------------------------
# 4 ULDs are built by the model
# 6 ULDs were actually built
# ---------------------------------------------------------------------------
# The ULDs are builded and blocked in the model:
# PMC-24
# ---------------------------------------------------------------------------
# Items deferred for ULD PMC-22:
# 62835301-2 deferred due to item does not fit in ULD
# 63009796 deferred due to item does not fit in ULD
# 63647253-2 deferred due to item does not fit in ULD
# ---------------------------------------------------------------------------
# Flag set: opening a new ULD
# Item 62835301-2 is causing the flag
# ---------------------------------------------------------------------------
# 3 items have been deferred this iteration
# 1 ULDs have deferred items this iteration
# Iteration 4
# ===========================================================================
# Starting optimization for iteration 4
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (mac64[arm] - Darwin 24.4.0 24E263)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 767080 rows, 214850 columns and 2922655 nonzeros
# Model fingerprint: 0x7b387329
# Variable types: 105487 continuous, 109363 integer (109363 binary)
# Coefficient statistics:
#   Matrix range     [7e-04, 1e+07]
#   Objective range  [5e-01, 4e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e-01, 5e+04]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 6 objectives...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve...
# ---------------------------------------------------------------------------
#
# Presolve removed 757900 rows and 210300 columns
# Presolve time: 0.16s
# Presolved: 9180 rows, 4550 columns, 36176 nonzeros
#
# Multi-objectives: optimize objective 1 () ...
# ---------------------------------------------------------------------------
#
# Presolve removed 3298 rows and 2424 columns
# Presolve time: 0.03s
# Presolved: 5882 rows, 2126 columns, 17943 nonzeros
# Variable types: 969 continuous, 1157 integer (1157 binary)
# Found heuristic solution: objective -27.2124429
#
# Root relaxation: objective -3.200653e+01, 210 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  -32.00653    0   27  -27.21244  -32.00653  17.6%     -    0s
# H    0     0                     -30.7304111  -32.00653  4.15%     -    0s
# H    0     0                     -31.2783961  -32.00653  2.33%     -    0s
# H    0     0                     -31.6109151  -32.00653  1.25%     -    0s
# H    0     0                     -31.8388734  -32.00653  0.53%     -    0s
# H    0     0                     -32.0018074  -32.00653  0.01%     -    0s
# H    0     0                     -32.0041727  -32.00653  0.01%     -    0s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 3
#   Implied bound: 2
#   Clique: 1
#   MIR: 1
#   StrongCG: 1
#   Zero half: 1
#   RLT: 15
#   Relax-and-lift: 11
#   BQP: 9
#
# Explored 1 nodes (874 simplex iterations) in 0.35 seconds (0.77 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: -32.0042 -32.0018 -31.8389 ... -27.2124
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -3.200417266049e+01, best bound -3.200653197214e+01, gap 0.0074%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 3.13087e+07
#
# Presolve removed 3299 rows and 2424 columns
# Presolve time: 0.03s
# Presolved: 5882 rows, 2126 columns, 17943 nonzeros
# Variable types: 969 continuous, 1157 integer (1157 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.39 seconds (0.83 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 3.13087e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.130867400000e+07, best bound 3.130867400000e+07, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 3 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 17
#
# Presolve removed 3322 rows and 2420 columns
# Presolve time: 0.05s
# Presolved: 5860 rows, 2130 columns, 19382 nonzeros
# Variable types: 969 continuous, 1161 integer (1157 binary)
#
# Root relaxation: objective 1.600000e+01, 218 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   16.00000    0    2   17.00000   16.00000  5.88%     -    0s
# H    0     0                      16.0000000   16.00000  0.00%     -    0s
#      0     0   16.00000    0    2   16.00000   16.00000  0.00%     -    0s
#
# Explored 1 nodes (968 simplex iterations) in 0.48 seconds (1.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 16 17
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.600000000000e+01, best bound 1.600000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 4 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 2
#
# Presolve removed 3320 rows and 2416 columns
# Presolve time: 0.06s
# Presolved: 5863 rows, 2134 columns, 19505 nonzeros
# Found heuristic solution: objective 0.4000000
# Variable types: 973 continuous, 1161 integer (1157 binary)
#
# Root relaxation: objective 0.000000e+00, 732 iterations, 0.02 seconds (0.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0   74    0.40000    0.00000   100%     -    0s
# H    0     0                       0.2528860    0.00000   100%     -    0s
# H    0     0                       0.2000000    0.00000   100%     -    0s
#      0     0    0.00000    0  131    0.20000    0.00000   100%     -    0s
#      0     0     cutoff    0         0.20000    0.20000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 2
#   Implied bound: 128
#   MIR: 2
#   Zero half: 7
#   RLT: 10
#
# Explored 1 nodes (3984 simplex iterations) in 0.92 seconds (1.83 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 0.2 0.252886 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e-01, best bound 2.000000000000e-01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 5 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 88
#
# Presolve removed 3297 rows and 2394 columns
# Presolve time: 0.06s
# Presolved: 5887 rows, 2156 columns, 19625 nonzeros
# Found heuristic solution: objective 66.0000000
# Variable types: 973 continuous, 1183 integer (1179 binary)
# Found heuristic solution: objective 54.0000000
#
# Root relaxation: objective 5.000000e+01, 413 iterations, 0.01 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   50.00000    0   78   54.00000   50.00000  7.41%     -    1s
# H    0     0                      53.0000000   50.00000  5.66%     -    1s
#      0     0   50.00000    0   20   53.00000   50.00000  5.66%     -    1s
# H    0     0                      52.0000000   50.00000  3.85%     -    1s
#      0     0   50.00000    0   12   52.00000   50.00000  3.85%     -    1s
#      0     0   50.00000    0   12   52.00000   50.00000  3.85%     -    1s
#      0     0   50.00000    0    4   52.00000   50.00000  3.85%     -    1s
#      0     0   50.00000    0   44   52.00000   50.00000  3.85%     -    1s
#      0     0   50.00000    0   12   52.00000   50.00000  3.85%     -    1s
# H    0     0                      51.0000000   50.00000  1.96%     -    1s
#      0     0   50.00000    0   12   51.00000   50.00000  1.96%     -    1s

# %% [markdown]
# **Run the model for a specific flight**

# %%
flight_number = 'KL0871'
departure_airport = 'AMS'
arrival_airport = 'DEL'
day = '05'
month = 'FEB'
year = '2024'
restricted_loadlocations = []

flight = filter_model.per_flight(flight_number = flight_number, departure_airport = departure_airport, arrival_airport = arrival_airport, day = day, month = month, year = year)

try:
    piece_information_csv = os.path.join(flight, 'PieceInformation.csv')
    flight_information_csv = os.path.join(flight, 'FlightInformation.csv')
    load_locations_csv = os.path.join(flight, 'LoadLocations.csv')
    pax_information_csv = os.path.join(flight, 'PaxInformation.csv')
    buildup_information_csv = os.path.join(flight, 'BuildUpInformation.csv')

    project_setup = ProjectSetup()
    cargo, aircraft, EP, plot, data_analysis = project_setup.setup_project(piece_information_csv, flight_information_csv, 
                                                            load_locations_csv, pax_information_csv, 
                                                            buildup_information_csv, arrival_airport, restricted_loadlocations,
                                                            baseline = True, optimized_actual = False, BAX_fixed=True)
    
    # %run Baseline.ipynb

except Exception as e:
    print(f"An error occurred while processing flight {flight_number}:")
    traceback.print_exc()
# Out:
# Running the model for Flight KL0871 AMSDEL 05 FEB 2024
# ========================================================================================================
# The model will run the following flight:
# --------------------------------------------------------------------------------------------------------
# Flight Number: KL871 PHBVR - Aircraft Type: 77W - Departure: AMS - Arrival: DEL - Date: 05 FEB 24
#
# ZFW: 217615.0 kg - TOW: 289942.0 kg - LW: 232365.0 kg - OEW: 171214.0 kg
#
# Fuel: 72327 kg - Trip Fuel: 57577 kg
#
# Number of Cargo ULDs used: 10
#
# Number of BAX ULDs: 16 - Number of BUP ULDs: 0 - Number of T ULDs: 3
# --------------------------------------------------------------------------------------------------------
# ULD set available for loading:
# AKE-26, AKE
# AKE-29, AKE
# AKE-30, AKE
# AKE-31, AKE
# AKE-32, AKE
# PMC-33, PMC
# PMC-38, PMC
# PMC-39, PMC
# PMC-40, PMC
# PMC-41, PMC
# --------------------------------------------------------------------------------------------------------
# BAX and BUP set for loading:
# BAX-0, AKE
# BAX-3, AKE
# BAX-4, AKE
# BAX-5, AKE
# BAX-7, AKE
# BAX-8, AKE
# BAX-10, AKE
# BAX-11, AKE
# BAX-12, AKE
# BAX-14, AKE
# BAX-15, AKE
# BAX-16, AKE
# BAX-17, AKE
# BAX-23, AKE
# BAX-24, AKE
# BAX-25, AKE
# T-42, PMC
# T-43, PMC
# T-44, AKE
# --------------------------------------------------------------------------------------------------------
# PAX allocation:
# PAX-A: 34
# PAX-B: 22
# PAX-C: 39
# PAX-D: 48
# PAX-E: 57
# PAX-F: 59
# PAX-G: 60
# Total PAX: 319
# --------------------------------------------------------------------------------------------------------
# Check if all items fit the ULDs dimensions:
#
# 93 / 93 items fit the dimensions of the ULDs
# --------------------------------------------------------------------------------------------------------
# Iteration 1
# ===========================================================================
# Starting optimization for iteration 1
# Set parameter Username
# Set parameter LicenseID to value 2656886
# Academic license - for non-commercial use only - expires 2026-04-25
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (mac64[arm] - Darwin 24.4.0 24E263)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2394 rows, 3191 columns and 15568 nonzeros
# Model fingerprint: 0xd18a26c0
# Variable types: 30 continuous, 3161 integer (3161 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 1e+07]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e-01, 1e+00]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 5 objectives...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve...
# ---------------------------------------------------------------------------
#
# Presolve removed 2091 rows and 1767 columns
# Presolve time: 0.01s
# Presolved: 303 rows, 1424 columns, 4360 nonzeros
#
# Multi-objectives: optimize objective 1 () ...
# ---------------------------------------------------------------------------
#
# Presolve removed 145 rows and 469 columns
# Presolve time: 0.00s
# Presolved: 158 rows, 955 columns, 3225 nonzeros
# Variable types: 0 continuous, 955 integer (940 binary)
# Found heuristic solution: objective 2.199083e+07
#
# Root relaxation: cutoff, 179 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      2.1991e+07 2.1991e+07  0.00%     -    0s
#
# Explored 1 nodes (179 simplex iterations) in 0.03 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 2.19908e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.199083300000e+07, best bound 2.199083300000e+07, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 10
#
# Presolve removed 140 rows and 464 columns
# Presolve time: 0.01s
# Presolved: 164 rows, 960 columns, 3340 nonzeros
# Variable types: 0 continuous, 960 integer (940 binary)
#
# Root relaxation: objective 3.181401e+00, 354 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    3.18140    0    6   10.00000    3.18140  68.2%     -    0s
# H    0     0                       5.0000000    3.18140  36.4%     -    0s
# H    0     0                       4.0000000    3.18140  20.5%     -    0s
#      0     0    3.18140    0    6    4.00000    3.18140  20.5%     -    0s
#
# Explored 1 nodes (354 simplex iterations) in 0.05 seconds (0.04 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 4 5 10
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.000000000000e+00, best bound 4.000000000000e+00, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 3 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 6
#
# Presolve removed 130 rows and 454 columns
# Presolve time: 0.01s
# Presolved: 175 rows, 970 columns, 3880 nonzeros
# Found heuristic solution: objective 1.2000000
# Variable types: 10 continuous, 960 integer (940 binary)
#
# Root relaxation: objective 1.560834e-01, 241 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.15608    0   19    1.20000    0.15608  87.0%     -    0s
#      0     0     cutoff    0         1.20000    1.20000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 5
#   Cover: 16
#   Implied bound: 12
#   Clique: 76
#   MIR: 1
#   StrongCG: 4
#   Flow cover: 3
#
# Explored 1 nodes (619 simplex iterations) in 0.09 seconds (0.07 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1.2 6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.200000000000e+00, best bound 1.200000000000e+00, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 4 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 150
#
# Presolve removed 40 rows and 349 columns
# Presolve time: 0.01s
# Presolved: 266 rows, 1075 columns, 4330 nonzeros
# Found heuristic solution: objective 109.0000000
# Variable types: 10 continuous, 1065 integer (1045 binary)
# Found heuristic solution: objective 34.0000000
#
# Root relaxation: objective 1.520000e+01, 681 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   15.20000    0   11   34.00000   15.20000  55.3%     -    0s
# H    0     0                      33.0000000   15.20000  53.9%     -    0s
# H    0     0                      32.0000000   15.20000  52.5%     -    0s
# H    0     0                      30.0000000   15.20000  49.3%     -    0s
# H    0     0                      22.0000000   15.20000  30.9%     -    0s
# H    0     0                      21.0000000   15.20000  27.6%     -    0s
# H    0     0                      17.0000000   15.20000  10.6%     -    0s
#      0     0   16.00000    0   14   17.00000   16.00000  5.88%     -    0s
# H    0     0                      16.0000000   16.00000  0.00%     -    0s
#      0     0   16.00000    0   14   16.00000   16.00000  0.00%     -    0s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 1
#   Cover: 5
#   Implied bound: 3
#   Clique: 57
#   MIR: 4
#   Flow cover: 2
#   RLT: 1
#   Relax-and-lift: 3
#
# Explored 1 nodes (1457 simplex iterations) in 0.16 seconds (0.14 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 16 17 21 ... 150
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.600000000000e+01, best bound 1.600000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 5  ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 0
#
#
# Explored 0 nodes (0 simplex iterations) in 0.16 seconds (0.14 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.17 seconds (0.14 work units), solution count 10
#
# Solution found
# Items deferred for ULD AKE-31:
# 64075900 deferred due to item does not fit in ULD
# ---------------------------------------------------------------------------
# Items deferred for ULD PMC-41:
# 63939363-3 deferred due to item does not fit in ULD
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# Number of deferred items: 2
# Number of opened ULDs: 4
# ---------------------------------------------------------------------------
# Flag set: opening a new ULD
# Item 64075900 is causing the flag
# ---------------------------------------------------------------------------
# Iteration 5
# ===========================================================================
# Starting optimization for iteration 5
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (mac64[arm] - Darwin 24.4.0 24E263)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2394 rows, 3191 columns and 15568 nonzeros
# Model fingerprint: 0xdb7f88f9
# Variable types: 30 continuous, 3161 integer (3161 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 1e+07]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e-01, 5e+00]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 5 objectives...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve...
# ---------------------------------------------------------------------------
#
# Presolve removed 2344 rows and 2714 columns
# Presolve time: 0.00s
# Presolved: 50 rows, 477 columns, 168 nonzeros
#
# Multi-objectives: optimize objective 1 () ...
# ---------------------------------------------------------------------------
#
# Found heuristic solution: objective 2.199083e+07
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 2.19908e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.199083300000e+07, best bound 2.199083300000e+07, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 24
#
# Presolve removed 27 rows and 450 columns
# Presolve time: 0.00s
# Presolved: 23 rows, 27 columns, 102 nonzeros
# Found heuristic solution: objective 5.0000000
# Variable types: 0 continuous, 27 integer (27 binary)
#
# Root relaxation: cutoff, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         5.00000    5.00000  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 5 24
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.000000000000e+00, best bound 5.000000000000e+00, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 3 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 5
#
# Presolve removed 22 rows and 444 columns
# Presolve time: 0.00s
# Presolved: 29 rows, 33 columns, 126 nonzeros
# Found heuristic solution: objective 1.0000000
# Variable types: 2 continuous, 31 integer (31 binary)
#
# Root relaxation: objective 8.000000e-01, 32 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.80000    0   10    1.00000    0.80000  20.0%     -    0s
#      0     0    0.87977    0    9    1.00000    0.87977  12.0%     -    0s
#      0     0    0.96335    0    7    1.00000    0.96335  3.67%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 3
#   Implied bound: 1
#   Clique: 4
#
# Explored 1 nodes (77 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1 5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 4 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 34
#
# Presolve removed 22 rows and 444 columns
# Presolve time: 0.00s
# Presolved: 30 rows, 33 columns, 133 nonzeros
# Found heuristic solution: objective 17.0000000
# Variable types: 2 continuous, 31 integer (31 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 17 34
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.700000000000e+01, best bound 1.700000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 5  ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 0
#
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.02 seconds (0.01 work units), solution count 4
#
# Solution found
# Items deferred for ULD AKE-29:
# 64075900 deferred due to item does not fit in ULD
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# Number of deferred items: 1
# Number of opened ULDs: 5
# ---------------------------------------------------------------------------
# Flag set: opening a new ULD
# Item 64075900 is causing the flag
# ---------------------------------------------------------------------------
# Iteration 10
# ===========================================================================
# Starting optimization for iteration 10
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (mac64[arm] - Darwin 24.4.0 24E263)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2394 rows, 3191 columns and 15568 nonzeros
# Model fingerprint: 0xdf1c9a38
# Variable types: 30 continuous, 3161 integer (3161 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 1e+07]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e-01, 6e+00]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 5 objectives...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve...
# ---------------------------------------------------------------------------
#
# Presolve removed 2344 rows and 2714 columns
# Presolve time: 0.00s
# Presolved: 50 rows, 477 columns, 168 nonzeros
#
# Multi-objectives: optimize objective 1 () ...
# ---------------------------------------------------------------------------
#
# Found heuristic solution: objective 2.199083e+07
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 2.19908e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.199083300000e+07, best bound 2.199083300000e+07, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 25
#
# Presolve removed 27 rows and 450 columns
# Presolve time: 0.00s
# Presolved: 23 rows, 27 columns, 102 nonzeros
# Found heuristic solution: objective 6.0000000
# Variable types: 0 continuous, 27 integer (27 binary)
#
# Root relaxation: cutoff, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         6.00000    6.00000  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 6 25
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.000000000000e+00, best bound 6.000000000000e+00, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 3 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 4
#
# Presolve removed 22 rows and 444 columns
# Presolve time: 0.00s
# Presolved: 29 rows, 33 columns, 126 nonzeros
# Found heuristic solution: objective 0.8000000
# Variable types: 2 continuous, 31 integer (31 binary)
#
# Root relaxation: cutoff, 18 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         0.80000    0.80000  0.00%     -    0s
#
# Explored 1 nodes (18 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 0.8 4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.000000000000e-01, best bound 8.000000000000e-01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 4 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 34
#
# Presolve removed 22 rows and 444 columns
# Presolve time: 0.00s
# Presolved: 30 rows, 33 columns, 133 nonzeros
# Found heuristic solution: objective 17.0000000
# Variable types: 2 continuous, 31 integer (31 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 17 34
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.700000000000e+01, best bound 1.700000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 5  ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 0
#
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.02 seconds (0.00 work units), solution count 4
#
# Solution found
# Items deferred for ULD AKE-26:
# 64075900 deferred due to item does not fit in ULD
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# Number of deferred items: 1
# Number of opened ULDs: 6
# ---------------------------------------------------------------------------
# Flag set: opening a new ULD
# Item 64075900 is causing the flag
# ---------------------------------------------------------------------------
# Iteration 16
# ===========================================================================
# Starting optimization for iteration 16
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (mac64[arm] - Darwin 24.4.0 24E263)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2394 rows, 3191 columns and 15568 nonzeros
# Model fingerprint: 0x1826845d
# Variable types: 30 continuous, 3161 integer (3161 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 1e+07]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e-01, 7e+00]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 5 objectives...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve...
# ---------------------------------------------------------------------------
#
# Presolve removed 2344 rows and 2714 columns
# Presolve time: 0.00s
# Presolved: 50 rows, 477 columns, 168 nonzeros
#
# Multi-objectives: optimize objective 1 () ...
# ---------------------------------------------------------------------------
#
# Presolve removed 27 rows and 450 columns
# Presolve time: 0.00s
# Presolved: 23 rows, 27 columns, 102 nonzeros
# Variable types: 0 continuous, 27 integer (27 binary)
#
# Root relaxation: infeasible, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 infeasible    0               - infeasible      -     -    0s
#
# Explored 1 nodes (17 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.01 seconds (0.00 work units)
# Model is infeasible
#
# The model is infeasible or unbounded
# Infeasibility report written to model.ilp
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /var/folders/tc/_8w7cdmd2dvfv79kbrjbdgd40000gp/T/ipykernel_89139/3738830361.py:1
# ----> 1 solve_baseline(cargo)
#
# File /var/folders/tc/_8w7cdmd2dvfv79kbrjbdgd40000gp/T/ipykernel_89139/2591594220.py:2, in solve_baseline(cargo)
#       1 def solve_baseline(cargo):
# ----> 2     results_3D_BPP, total_time_1D_BBP, total_time_3D_BPP = feedback_loop(cargo)
#       3     total_time_WB, folder_path = solve_WB(cargo, results_3D_BPP)
#       5     model_info_path = os.path.join(folder_path, 'Model_Information.txt')
#
# File /var/folders/tc/_8w7cdmd2dvfv79kbrjbdgd40000gp/T/ipykernel_89139/1581554062.py:26, in feedback_loop(cargo)
#      24 print(f'Starting optimization for iteration {iteration}')
#      25 start_time_1D_BPP = time.time()
# ---> 26 results_1D_BPP, loadfactor_dict = solve_1D_BPP_WB(cargo, deferred_items = deferred_items, attempted_combinations = attempted_combinations,
#      27                                                                                                            number_of_opened_uld = number_of_opened_uld, packed_ULDs = packed_ULDs,
#      28                                                                                                            open_new_uld = open_new_uld, open_new_extra_uld = open_new_extra_uld,
#      29                                                                                                            deferred_items_optimal_flag = False)
#      30 open_new_extra_uld = False
#      31 total_time_1D_BPP += time.time() - start_time_1D_BPP
#
# File /var/folders/tc/_8w7cdmd2dvfv79kbrjbdgd40000gp/T/ipykernel_89139/1911969313.py:215, in solve_1D_BPP_WB(cargo, deferred_items, attempted_combinations, number_of_opened_uld, packed_ULDs, open_new_uld, open_new_extra_uld, deferred_items_optimal_flag)
#     212 results_1D_BPP_WB = {}
#     214 for j in cargo.uld:
# --> 215     if u[j.index].x == 1:
#     216         if j.isNeitherBAXnorBUPnorT:
#     217             results_1D_BPP_WB[j] = []
#
# File src/gurobipy/var.pxi:128, in gurobipy._core.Var.__getattr__()
#
# File src/gurobipy/var.pxi:156, in gurobipy._core.Var.getAttr()
#
# File src/gurobipy/_attrutil.pyx:117, in gurobipy._attrutil._getattr()
#
# AttributeError: Unable to retrieve attribute 'x'
# An error occurred while processing flight KL0871:
# Traceback (most recent call last):
#   File "/var/folders/tc/_8w7cdmd2dvfv79kbrjbdgd40000gp/T/ipykernel_89139/3111643736.py", line 24, in <module>
#     get_ipython().run_line_magic('run', 'Baseline.ipynb')
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2480, in run_line_magic
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/magics/execution.py", line 737, in run
#     self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3005, in safe_execfile_ipy
#     result.raise_error()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 308, in raise_error
#     raise self.error_in_exec
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/tc/_8w7cdmd2dvfv79kbrjbdgd40000gp/T/ipykernel_89139/3738830361.py", line 1, in <module>
#     solve_baseline(cargo)
#   File "/var/folders/tc/_8w7cdmd2dvfv79kbrjbdgd40000gp/T/ipykernel_89139/2591594220.py", line 2, in solve_baseline
#     results_3D_BPP, total_time_1D_BBP, total_time_3D_BPP = feedback_loop(cargo)
#                                                            ^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/tc/_8w7cdmd2dvfv79kbrjbdgd40000gp/T/ipykernel_89139/1581554062.py", line 26, in feedback_loop
#     results_1D_BPP, loadfactor_dict = solve_1D_BPP_WB(cargo, deferred_items = deferred_items, attempted_combinations = attempted_combinations,
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/tc/_8w7cdmd2dvfv79kbrjbdgd40000gp/T/ipykernel_89139/1911969313.py", line 215, in solve_1D_BPP_WB
#     if u[j.index].x == 1:
#        ^^^^^^^^^^^^
#   File "src/gurobipy/var.pxi", line 128, in gurobipy._core.Var.__getattr__
#   File "src/gurobipy/var.pxi", line 156, in gurobipy._core.Var.getAttr
#   File "src/gurobipy/_attrutil.pyx", line 117, in gurobipy._attrutil._getattr
# AttributeError: Unable to retrieve attribute 'x'

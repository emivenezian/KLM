# %%
# %run Classes.ipynb

# %%
filter_model = FilterData()

# %% [markdown]
# **KL855 AMS --> ICN**

# %%
departure_airport = 'AMS'
arrival_airport = 'ICN'
month = 'JAN'
year = '2024'

results_reader = ResultsReaderOptimizedActual(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_baseline_results(df)
# Out:
# <style type="text/css">
# #T_b8e2b th.col-1 {
#   text-align: left;
# }
# #T_b8e2b td.col-1 {
#   text-align: center;
# }
# #T_b8e2b_row0_col0, #T_b8e2b_row1_col0, #T_b8e2b_row2_col0, #T_b8e2b_row3_col0, #T_b8e2b_row4_col0, #T_b8e2b_row5_col0, #T_b8e2b_row6_col0, #T_b8e2b_row7_col0, #T_b8e2b_row8_col0, #T_b8e2b_row9_col0, #T_b8e2b_row10_col0, #T_b8e2b_row11_col0, #T_b8e2b_row12_col0, #T_b8e2b_row13_col0, #T_b8e2b_row14_col0, #T_b8e2b_row15_col0, #T_b8e2b_row16_col0, #T_b8e2b_row17_col0, #T_b8e2b_row18_col0 {
#   text-align: left;
# }
# #T_b8e2b_row19_col0, #T_b8e2b_row20_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %%
departure_airport = 'AMS'
arrival_airport = 'ICN'
month = 'FEB'
year = '2024'

results_reader = ResultsReaderOptimizedActual(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_baseline_results(df)
# Out:
# <style type="text/css">
# #T_785e5 th.col-1 {
#   text-align: left;
# }
# #T_785e5 td.col-1 {
#   text-align: center;
# }
# #T_785e5_row0_col0, #T_785e5_row1_col0, #T_785e5_row2_col0, #T_785e5_row3_col0, #T_785e5_row4_col0, #T_785e5_row5_col0, #T_785e5_row6_col0, #T_785e5_row7_col0, #T_785e5_row8_col0, #T_785e5_row9_col0, #T_785e5_row10_col0, #T_785e5_row11_col0, #T_785e5_row12_col0, #T_785e5_row13_col0, #T_785e5_row14_col0, #T_785e5_row15_col0, #T_785e5_row16_col0, #T_785e5_row17_col0, #T_785e5_row18_col0, #T_785e5_row19_col0, #T_785e5_row20_col0, #T_785e5_row21_col0 {
#   text-align: left;
# }
# #T_785e5_row22_col0, #T_785e5_row23_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %%
departure_airport = 'AMS'
arrival_airport = 'ICN'
month = 'MAR'
year = '2024'

results_reader = ResultsReaderOptimizedActual(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_baseline_results(df)
# Out:
# <style type="text/css">
# #T_c0c47 th.col-1 {
#   text-align: left;
# }
# #T_c0c47 td.col-1 {
#   text-align: center;
# }
# #T_c0c47_row0_col0, #T_c0c47_row1_col0, #T_c0c47_row2_col0, #T_c0c47_row3_col0, #T_c0c47_row4_col0, #T_c0c47_row5_col0, #T_c0c47_row6_col0, #T_c0c47_row7_col0, #T_c0c47_row8_col0, #T_c0c47_row9_col0, #T_c0c47_row10_col0, #T_c0c47_row11_col0, #T_c0c47_row12_col0, #T_c0c47_row13_col0, #T_c0c47_row14_col0, #T_c0c47_row15_col0, #T_c0c47_row16_col0, #T_c0c47_row17_col0, #T_c0c47_row18_col0, #T_c0c47_row19_col0, #T_c0c47_row20_col0, #T_c0c47_row21_col0, #T_c0c47_row22_col0 {
#   text-align: left;
# }
# #T_c0c47_row23_col0, #T_c0c47_row24_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %% [markdown]
# **KL661 AMS --> IAH**

# %%
departure_airport = 'AMS'
arrival_airport = 'IAH'
month = 'JAN'
year = '2024'

results_reader = ResultsReaderOptimizedActual(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_baseline_results(df)
# Out:
# <style type="text/css">
# #T_02596 th.col-1 {
#   text-align: left;
# }
# #T_02596 td.col-1 {
#   text-align: center;
# }
# #T_02596_row0_col0, #T_02596_row1_col0, #T_02596_row2_col0, #T_02596_row3_col0, #T_02596_row4_col0, #T_02596_row5_col0, #T_02596_row6_col0, #T_02596_row7_col0, #T_02596_row8_col0, #T_02596_row9_col0, #T_02596_row10_col0, #T_02596_row11_col0, #T_02596_row12_col0, #T_02596_row13_col0, #T_02596_row14_col0, #T_02596_row15_col0, #T_02596_row16_col0, #T_02596_row17_col0, #T_02596_row18_col0, #T_02596_row19_col0, #T_02596_row20_col0, #T_02596_row21_col0 {
#   text-align: left;
# }
# #T_02596_row22_col0, #T_02596_row23_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %%
departure_airport = 'AMS'
arrival_airport = 'IAH'
month = 'FEB'
year = '2024'

results_reader = ResultsReaderOptimizedActual(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_baseline_results(df)
# Out:
# <style type="text/css">
# #T_0d5e9 th.col-1 {
#   text-align: left;
# }
# #T_0d5e9 td.col-1 {
#   text-align: center;
# }
# #T_0d5e9_row0_col0, #T_0d5e9_row1_col0, #T_0d5e9_row2_col0, #T_0d5e9_row3_col0, #T_0d5e9_row4_col0, #T_0d5e9_row5_col0, #T_0d5e9_row6_col0, #T_0d5e9_row7_col0, #T_0d5e9_row8_col0, #T_0d5e9_row9_col0, #T_0d5e9_row10_col0, #T_0d5e9_row11_col0, #T_0d5e9_row12_col0, #T_0d5e9_row13_col0, #T_0d5e9_row14_col0, #T_0d5e9_row15_col0, #T_0d5e9_row16_col0 {
#   text-align: left;
# }
# #T_0d5e9_row17_col0, #T_0d5e9_row18_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %%
departure_airport = 'AMS'
arrival_airport = 'IAH'
month = 'MAR'
year = '2024'

results_reader = ResultsReaderOptimizedActual(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_baseline_results(df)
# Out:
# <style type="text/css">
# #T_296b7 th.col-1 {
#   text-align: left;
# }
# #T_296b7 td.col-1 {
#   text-align: center;
# }
# #T_296b7_row0_col0, #T_296b7_row1_col0, #T_296b7_row2_col0, #T_296b7_row3_col0, #T_296b7_row4_col0, #T_296b7_row5_col0, #T_296b7_row6_col0, #T_296b7_row7_col0, #T_296b7_row8_col0, #T_296b7_row9_col0, #T_296b7_row10_col0, #T_296b7_row11_col0, #T_296b7_row12_col0, #T_296b7_row13_col0, #T_296b7_row14_col0, #T_296b7_row15_col0, #T_296b7_row16_col0, #T_296b7_row17_col0, #T_296b7_row18_col0, #T_296b7_row19_col0, #T_296b7_row20_col0, #T_296b7_row21_col0 {
#   text-align: left;
# }
# #T_296b7_row22_col0, #T_296b7_row23_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %% [markdown]
# **KL835 AMS --> SIN**

# %%
departure_airport = 'AMS'
arrival_airport = 'SIN'
month = 'JAN'
year = '2024'

results_reader = ResultsReaderOptimizedActual(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_baseline_results(df)
# Out:
# <style type="text/css">
# #T_aea21 th.col-1 {
#   text-align: left;
# }
# #T_aea21 td.col-1 {
#   text-align: center;
# }
# #T_aea21_row0_col0, #T_aea21_row1_col0, #T_aea21_row2_col0, #T_aea21_row3_col0, #T_aea21_row4_col0, #T_aea21_row5_col0, #T_aea21_row6_col0, #T_aea21_row7_col0, #T_aea21_row8_col0, #T_aea21_row9_col0, #T_aea21_row10_col0, #T_aea21_row11_col0, #T_aea21_row12_col0, #T_aea21_row13_col0, #T_aea21_row14_col0, #T_aea21_row15_col0, #T_aea21_row16_col0, #T_aea21_row17_col0, #T_aea21_row18_col0, #T_aea21_row19_col0, #T_aea21_row20_col0, #T_aea21_row21_col0, #T_aea21_row22_col0, #T_aea21_row23_col0, #T_aea21_row24_col0, #T_aea21_row25_col0, #T_aea21_row26_col0 {
#   text-align: left;
# }
# #T_aea21_row27_col0, #T_aea21_row28_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %%
departure_airport = 'AMS'
arrival_airport = 'SIN'
month = 'FEB'
year = '2024'

results_reader = ResultsReaderOptimizedActual(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_baseline_results(df)
# Out:
# <style type="text/css">
# #T_3300c th.col-1 {
#   text-align: left;
# }
# #T_3300c td.col-1 {
#   text-align: center;
# }
# #T_3300c_row0_col0, #T_3300c_row1_col0, #T_3300c_row2_col0, #T_3300c_row3_col0, #T_3300c_row4_col0, #T_3300c_row5_col0, #T_3300c_row6_col0, #T_3300c_row7_col0, #T_3300c_row8_col0, #T_3300c_row9_col0, #T_3300c_row10_col0, #T_3300c_row11_col0, #T_3300c_row12_col0, #T_3300c_row13_col0, #T_3300c_row14_col0, #T_3300c_row15_col0, #T_3300c_row16_col0, #T_3300c_row17_col0, #T_3300c_row18_col0, #T_3300c_row19_col0, #T_3300c_row20_col0, #T_3300c_row21_col0, #T_3300c_row22_col0 {
#   text-align: left;
# }
# #T_3300c_row23_col0, #T_3300c_row24_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %%
departure_airport = 'AMS'
arrival_airport = 'SIN'
month = 'MAR'
year = '2024'

results_reader = ResultsReaderOptimizedActual(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_baseline_results(df)
# Out:
# <style type="text/css">
# #T_06127 th.col-1 {
#   text-align: left;
# }
# #T_06127 td.col-1 {
#   text-align: center;
# }
# #T_06127_row0_col0, #T_06127_row1_col0, #T_06127_row2_col0, #T_06127_row3_col0, #T_06127_row4_col0, #T_06127_row5_col0, #T_06127_row6_col0, #T_06127_row7_col0, #T_06127_row8_col0, #T_06127_row9_col0, #T_06127_row10_col0, #T_06127_row11_col0, #T_06127_row12_col0, #T_06127_row13_col0, #T_06127_row14_col0, #T_06127_row15_col0, #T_06127_row16_col0, #T_06127_row17_col0, #T_06127_row18_col0, #T_06127_row19_col0, #T_06127_row20_col0, #T_06127_row21_col0 {
#   text-align: left;
# }
# #T_06127_row22_col0, #T_06127_row23_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %% [markdown]
# **KL601 AMS --> LAX**

# %%
departure_airport = 'AMS'
arrival_airport = 'LAX'
month = 'JAN'
year = '2024'

results_reader = ResultsReaderOptimizedActual(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_baseline_results(df)
# Out:
# <style type="text/css">
# #T_68371 th.col-1 {
#   text-align: left;
# }
# #T_68371 td.col-1 {
#   text-align: center;
# }
# #T_68371_row0_col0, #T_68371_row1_col0, #T_68371_row2_col0, #T_68371_row3_col0, #T_68371_row4_col0, #T_68371_row5_col0, #T_68371_row6_col0, #T_68371_row7_col0, #T_68371_row8_col0, #T_68371_row9_col0, #T_68371_row10_col0, #T_68371_row11_col0, #T_68371_row12_col0, #T_68371_row13_col0, #T_68371_row14_col0, #T_68371_row15_col0 {
#   text-align: left;
# }
# #T_68371_row16_col0, #T_68371_row17_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %%
departure_airport = 'AMS'
arrival_airport = 'LAX'
month = 'FEB'
year = '2024'

results_reader = ResultsReaderOptimizedActual(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_baseline_results(df)
# Out:
# <style type="text/css">
# #T_aefc2 th.col-1 {
#   text-align: left;
# }
# #T_aefc2 td.col-1 {
#   text-align: center;
# }
# #T_aefc2_row0_col0, #T_aefc2_row1_col0, #T_aefc2_row2_col0, #T_aefc2_row3_col0, #T_aefc2_row4_col0, #T_aefc2_row5_col0, #T_aefc2_row6_col0, #T_aefc2_row7_col0, #T_aefc2_row8_col0, #T_aefc2_row9_col0, #T_aefc2_row10_col0, #T_aefc2_row11_col0, #T_aefc2_row12_col0, #T_aefc2_row13_col0, #T_aefc2_row14_col0, #T_aefc2_row15_col0, #T_aefc2_row16_col0 {
#   text-align: left;
# }
# #T_aefc2_row17_col0, #T_aefc2_row18_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %%
departure_airport = 'AMS'
arrival_airport = 'LAX'
month = 'MAR'
year = '2024'

results_reader = ResultsReaderOptimizedActual(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_baseline_results(df)
# Out:
# <style type="text/css">
# #T_ee686 th.col-1 {
#   text-align: left;
# }
# #T_ee686 td.col-1 {
#   text-align: center;
# }
# #T_ee686_row0_col0, #T_ee686_row1_col0, #T_ee686_row2_col0, #T_ee686_row3_col0, #T_ee686_row4_col0, #T_ee686_row5_col0, #T_ee686_row6_col0, #T_ee686_row7_col0, #T_ee686_row8_col0, #T_ee686_row9_col0, #T_ee686_row10_col0, #T_ee686_row11_col0 {
#   text-align: left;
# }
# #T_ee686_row12_col0, #T_ee686_row13_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %% [markdown]
# **All Flights ICN, IAH, SIN, LAX**

# %%
results_reader = ResultsReaderOptimizedActual()
df = results_reader.read_all_results()
results_reader.style_baseline_results(df)
# Out:
# <style type="text/css">
# #T_656de th.col-1 {
#   text-align: left;
# }
# #T_656de td.col-1 {
#   text-align: center;
# }
# ...

# %%
# %run Classes.ipynb

# %%
filter_model = FilterData()

# %% [markdown]
# **Run the model for a specific month**

# %%
# departure_airport = 'AMS'
# arrival_airport = 'SIN'
# month = 'FEB'
# year = '2024'

# filtered_flights = filter_model.per_month(departure_airport = departure_airport, arrival_airport = arrival_airport, 
#                                           month = month, year = year)

# for flight_dir in filtered_flights:
#     try:
#         piece_information_csv = os.path.join(flight_dir, 'PieceInformation.csv')
#         flight_information_csv = os.path.join(flight_dir, 'FlightInformation.csv')
#         load_locations_csv = os.path.join(flight_dir, 'LoadLocations.csv')
#         pax_information_csv = os.path.join(flight_dir, 'PaxInformation.csv')
#         buildup_information_csv = os.path.join(flight_dir, 'BuildUpInformation.csv')

#         project_setup = ProjectSetup()
#         cargo, aircraft, EP, plot, data_analysis = project_setup.setup_project(piece_information_csv, flight_information_csv, 
#                                                                 load_locations_csv, pax_information_csv, 
#                                                                 buildup_information_csv, arrival_airport, 
#                                                                 baseline = True, optimized_actual = False)
        
#         %run Baseline.ipynb


#     except Exception as e:
#         traceback.print_exc()
#         continue

# %% [markdown]
# **Run the model for a specific flight**

# %%
flight_number = 'KL0855'
departure_airport = 'AMS'
arrival_airport = 'ICN'
day = '21'
month = 'FEB'
year = '2024'
restricted_loadlocations = []

flight = filter_model.per_flight(flight_number = flight_number, departure_airport = departure_airport, arrival_airport = arrival_airport, day = day, month = month, year = year)

try:
    piece_information_csv = os.path.join(flight, 'PieceInformation.csv')
    flight_information_csv = os.path.join(flight, 'FlightInformation.csv')
    load_locations_csv = os.path.join(flight, 'LoadLocations.csv')
    pax_information_csv = os.path.join(flight, 'PaxInformation.csv')
    buildup_information_csv = os.path.join(flight, 'BuildUpInformation.csv')

    project_setup = ProjectSetup()
    cargo, aircraft, EP, plot, data_analysis = project_setup.setup_project(piece_information_csv, flight_information_csv, 
                                                            load_locations_csv, pax_information_csv, 
                                                            buildup_information_csv, arrival_airport, restricted_loadlocations,
                                                            baseline = True, optimized_actual = False)
    
    # %run Baseline.ipynb

except Exception as e:
    print(f"An error occurred while processing flight {flight_number}:")
    traceback.print_exc()
# Out:
# Running the model for Flight KL0855 AMSICN 21 FEB 2024
# ========================================================================================================
# 43R
# 44L
# 44R
# 41L
# 33R
# 43L
# 33L
# 41R
# 32R
# The model will run the following flight:
# --------------------------------------------------------------------------------------------------------
# Flight Number: KL855 PHBQD - Aircraft Type: 772 - Departure: AMS - Arrival: ICN - Date: 21 FEB 24
#
# ZFW: 186113.6 kg - TOW: 266582.6 kg - LW: 191517.6 kg - OEW: 148459.0 kg
#
# Fuel: 80469 kg - Trip Fuel: 75065 kg
#
# Number of Cargo ULDs used: 3
#
# Number of BAX ULDs: 9 - Number of BUP ULDs: 0 - Number of T ULDs: 5
# --------------------------------------------------------------------------------------------------------
# ULD set available for loading:
# PAG-18, PAG
# PAG-20, PAG
# PAG-23, PAG
# --------------------------------------------------------------------------------------------------------
# BAX and BUP set for loading:
# BAX-0, AKE
# BAX-1, AKE
# BAX-3, AKE
# BAX-4, AKE
# BAX-6, AKE
# BAX-7, AKE
# BAX-8, AKE
# BAX-9, AKE
# BAX-11, AKE
# T-24, PMC
# T-25, PMC
# T-26, PMC
# T-27, PMC
# T-28, AKE
# --------------------------------------------------------------------------------------------------------
# PAX allocation:
# PAX-A: 28
# PAX-B: 32
# PAX-C: 115
# PAX-D: 53
# PAX-E: 72
# PAX-F: 0
# PAX-G: 0
# Total PAX: 300
# --------------------------------------------------------------------------------------------------------
# Check if all items fit the ULDs dimensions:
#
# 37 / 37 items fit the dimensions of the ULDs
# --------------------------------------------------------------------------------------------------------
# Iteration 1
# ===========================================================================
# Starting optimization for iteration 1
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1265U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 874 rows, 927 columns and 3646 nonzeros
# Model fingerprint: 0x8208d155
# Variable types: 9 continuous, 918 integer (918 binary)
# Coefficient statistics:
#   Matrix range     [4e-04, 1e+07]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e-01, 1e+00]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 5 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 774 rows and 521 columns
# Presolve time: 0.00s
# Presolved: 100 rows, 406 columns, 798 nonzeros
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 () ...
# ---------------------------------------------------------------------------
#
# Presolve removed 51 rows and 292 columns
# Presolve time: 0.00s
# Presolved: 49 rows, 114 columns, 486 nonzeros
# Variable types: 0 continuous, 114 integer (114 binary)
# Found heuristic solution: objective 8022360.0000
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 8.02236e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.022360000000e+06, best bound 8.022360000000e+06, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 3
#
# Presolve removed 48 rows and 289 columns
# Presolve time: 0.00s
# Presolved: 53 rows, 117 columns, 561 nonzeros
# Variable types: 0 continuous, 117 integer (114 binary)
#
# Root relaxation: objective 1.822811e+00, 151 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.82281    0    3    3.00000    1.82281  39.2%     -    0s
# H    0     0                       2.0000000    1.82281  8.86%     -    0s
#      0     0    1.82281    0    3    2.00000    1.82281  8.86%     -    0s
#
# Explored 1 nodes (151 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 2 3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 3 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 1
#
# Presolve removed 45 rows and 286 columns
# Presolve time: 0.00s
# Presolved: 57 rows, 120 columns, 678 nonzeros
# Found heuristic solution: objective 0.2000000
# Variable types: 3 continuous, 117 integer (114 binary)
#
# Root relaxation: objective 0.000000e+00, 46 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 infeasible    0         0.20000    0.20000  0.00%     -    0s
#
# Explored 1 nodes (46 simplex iterations) in 0.07 seconds (0.01 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.2 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e-01, best bound 2.000000000000e-01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 4 () ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 48
#
# Presolve removed 27 rows and 265 columns
# Presolve time: 0.00s
# Presolved: 76 rows, 141 columns, 753 nonzeros
# Found heuristic solution: objective 18.0000000
# Variable types: 3 continuous, 138 integer (135 binary)
#
# Root relaxation: objective 1.657143e+01, 84 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   16.57143    0    4   18.00000   16.57143  7.94%     -    0s
# H    0     0                      17.0000000   16.57143  2.52%     -    0s
#      0     0   16.57143    0    4   17.00000   16.57143  2.52%     -    0s
#
# Explored 1 nodes (173 simplex iterations) in 0.12 seconds (0.01 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 17 18 48
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.700000000000e+01, best bound 1.700000000000e+01, gap 0.0000%
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 5  ...
# ---------------------------------------------------------------------------
#
#
# Loaded user MIP start with objective 0
#
#
# Explored 0 nodes (0 simplex iterations) in 0.15 seconds (0.01 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.16 seconds (0.01 work units), solution count 5
#
# Solution found
# Solution found with no deferred items
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_15300\3738830361.py:1
# ----> 1 solve_baseline(cargo)
#
# File ~\AppData\Local\Temp\ipykernel_15300\2591594220.py:3, in solve_baseline(cargo)
#       1 def solve_baseline(cargo):
#       2     results_3D_BPP, total_time_1D_BBP, total_time_3D_BPP = feedback_loop(cargo)
# ----> 3     total_time_WB, folder_path = solve_WB(cargo, results_3D_BPP)
#       5     model_info_path = os.path.join(folder_path, 'Model_Information.txt')
#       7     with open(model_info_path, 'w') as file:
#
# File ~\AppData\Local\Temp\ipykernel_15300\3190009117.py:81, in solve_WB(cargo, results_3D_BPP)
#      79         if j_1 != j_2:
#      80             for t_1 in aircraft.loadlocations:
# ---> 81                     for t_2 in aircraft.define_overlapping_positions(t_1):
#      82                         m.addConstr(f[j_1.index, t_1.index] + f[j_2.index, t_2.index] <= 1, name = f'C6_{j_1.index}_{j_2.index}_{t_1.index}_{t_2.index}')
#      84 #The weight of a ULD assigned to a position should not exceed the maximum allowable weight. [Positions weight limit]
#
# File ~\AppData\Local\Temp\ipykernel_15300\2134834768.py:129, in Aircraft.define_overlapping_positions(self, position)
#     127 #Reading the file and creating a list of overlapping LoadLocations objects
#     128 overlapping = []
# --> 129 data = pd.read_csv(self.aircraft_filename, converters={'Overlapping': lambda x: x.split(',')})
#     130 data = data[data['ACType'] == str(self.aircraft_type)]
#     131 list_pos = data[data.LoadLocation == position.location]['Overlapping']
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:616, in _read(filepath_or_buffer, kwds)
#     613 if chunksize or iterator:
#     614     return parser
# --> 616 with parser:
#     617     return parser.read(nrows)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1788, in TextFileReader.__exit__(self, exc_type, exc_value, traceback)
#    1782 def __exit__(
#    1783     self,
#    1784     exc_type: type[BaseException] | None,
#    1785     exc_value: BaseException | None,
#    1786     traceback: TracebackType | None,
#    1787 ) -> None:
# -> 1788     self.close()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1452, in TextFileReader.close(self)
#    1450 def close(self) -> None:
#    1451     if self.handles is not None:
# -> 1452         self.handles.close()
#    1453     self._engine.close()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\common.py:134, in IOHandles.close(self)
#     132     self.created_handles.remove(self.handle)
#     133 for handle in self.created_handles:
# --> 134     handle.close()
#     135 self.created_handles = []
#     136 self.is_wrapped = False
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 24
#      18     project_setup = ProjectSetup()
#      19     cargo, aircraft, EP, plot, data_analysis = project_setup.setup_project(piece_information_csv, flight_information_csv,
#      20                                                             load_locations_csv, pax_information_csv,
#      21                                                             buildup_information_csv, arrival_airport, restricted_loadlocations,
#      22                                                             baseline = True, optimized_actual = False)
# ---> 24     get_ipython().run_line_magic('run', 'Baseline.ipynb')
#      26 except Exception as e:
#      27     print(f"An error occurred while processing flight {flight_number}:")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\interactiveshell.py:2456, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2454     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2455 with self.builtin_trap:
# -> 2456     result = fn(*args, **kwargs)
#    2458 # The code below prevents the output from being displayed
#    2459 # when using magics with decorator @output_can_be_silenced
#    2460 # when the last Python token in the expression is a ';'.
#    2461 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\magics\execution.py:737, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     735     with preserve_keys(self.shell.user_ns, '__file__'):
#     736         self.shell.user_ns['__file__'] = filename
# --> 737         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     738     return
#     740 # Control the response to exit() calls made by the script being run
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\interactiveshell.py:2978, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2976 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2977 if raise_exceptions:
# -> 2978     result.raise_error()
#    2979 elif not result.success:
#    2980     break
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\interactiveshell.py:294, in ExecutionResult.raise_error(self)
#     292     raise self.error_before_exec
#     293 if self.error_in_exec is not None:
# --> 294     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Local\Temp\ipykernel_15300\3738830361.py:1
# ----> 1 solve_baseline(cargo)
#
# File ~\AppData\Local\Temp\ipykernel_15300\2591594220.py:3, in solve_baseline(cargo)
#       1 def solve_baseline(cargo):
#       2     results_3D_BPP, total_time_1D_BBP, total_time_3D_BPP = feedback_loop(cargo)
# ----> 3     total_time_WB, folder_path = solve_WB(cargo, results_3D_BPP)
#       5     model_info_path = os.path.join(folder_path, 'Model_Information.txt')
#       7     with open(model_info_path, 'w') as file:
#
# File ~\AppData\Local\Temp\ipykernel_15300\3190009117.py:81, in solve_WB(cargo, results_3D_BPP)
#      79         if j_1 != j_2:
#      80             for t_1 in aircraft.loadlocations:
# ---> 81                     for t_2 in aircraft.define_overlapping_positions(t_1):
#      82                         m.addConstr(f[j_1.index, t_1.index] + f[j_2.index, t_2.index] <= 1, name = f'C6_{j_1.index}_{j_2.index}_{t_1.index}_{t_2.index}')
#      84 #The weight of a ULD assigned to a position should not exceed the maximum allowable weight. [Positions weight limit]
#
# File ~\AppData\Local\Temp\ipykernel_15300\2134834768.py:129, in Aircraft.define_overlapping_positions(self, position)
#     127 #Reading the file and creating a list of overlapping LoadLocations objects
#     128 overlapping = []
# --> 129 data = pd.read_csv(self.aircraft_filename, converters={'Overlapping': lambda x: x.split(',')})
#     130 data = data[data['ACType'] == str(self.aircraft_type)]
#     131 list_pos = data[data.LoadLocation == position.location]['Overlapping']
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:616, in _read(filepath_or_buffer, kwds)
#     613 if chunksize or iterator:
#     614     return parser
# --> 616 with parser:
#     617     return parser.read(nrows)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1788, in TextFileReader.__exit__(self, exc_type, exc_value, traceback)
#    1782 def __exit__(
#    1783     self,
#    1784     exc_type: type[BaseException] | None,
#    1785     exc_value: BaseException | None,
#    1786     traceback: TracebackType | None,
#    1787 ) -> None:
# -> 1788     self.close()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1452, in TextFileReader.close(self)
#    1450 def close(self) -> None:
#    1451     if self.handles is not None:
# -> 1452         self.handles.close()
#    1453     self._engine.close()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\common.py:134, in IOHandles.close(self)
#     132     self.created_handles.remove(self.handle)
#     133 for handle in self.created_handles:
# --> 134     handle.close()
#     135 self.created_handles = []
#     136 self.is_wrapped = False
#
# KeyboardInterrupt:

# %%
# %run Classes.ipynb

# %%
filter_model = FilterData()

# %% [markdown]
# **KL855 AMS --> ICN**

# %%
departure_airport = 'AMS'
arrival_airport = 'ICN'
month = 'JAN'
year = '2024'

results_reader = ResultsReaderBaseline(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_baseline_results(df)
# Out:
# <style type="text/css">
# #T_4e0e0 th.col-1 {
#   text-align: left;
# }
# #T_4e0e0 td.col-1 {
#   text-align: center;
# }
# #T_4e0e0_row0_col0, #T_4e0e0_row1_col0, #T_4e0e0_row2_col0, #T_4e0e0_row3_col0, #T_4e0e0_row4_col0, #T_4e0e0_row5_col0, #T_4e0e0_row6_col0, #T_4e0e0_row7_col0, #T_4e0e0_row8_col0, #T_4e0e0_row9_col0, #T_4e0e0_row10_col0, #T_4e0e0_row11_col0, #T_4e0e0_row12_col0 {
#   text-align: left;
# }
# #T_4e0e0_row13_col0, #T_4e0e0_row14_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %%
departure_airport = 'AMS'
arrival_airport = 'ICN'
month = 'FEB'
year = '2024'

results_reader = ResultsReaderBaseline(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_baseline_results(df)
# Out:
# <style type="text/css">
# #T_457c4 th.col-1 {
#   text-align: left;
# }
# #T_457c4 td.col-1 {
#   text-align: center;
# }
# #T_457c4_row0_col0, #T_457c4_row1_col0, #T_457c4_row2_col0, #T_457c4_row3_col0, #T_457c4_row4_col0, #T_457c4_row5_col0, #T_457c4_row6_col0, #T_457c4_row7_col0, #T_457c4_row8_col0, #T_457c4_row9_col0, #T_457c4_row10_col0, #T_457c4_row11_col0, #T_457c4_row12_col0, #T_457c4_row13_col0, #T_457c4_row14_col0, #T_457c4_row15_col0, #T_457c4_row16_col0, #T_457c4_row17_col0 {
#   text-align: left;
# }
# #T_457c4_row18_col0, #T_457c4_row19_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %%
departure_airport = 'AMS'
arrival_airport = 'ICN'
month = 'MAR'
year = '2024'

results_reader = ResultsReaderBaseline(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_baseline_results(df)
# Out:
# <style type="text/css">
# #T_63cbe th.col-1 {
#   text-align: left;
# }
# #T_63cbe td.col-1 {
#   text-align: center;
# }
# #T_63cbe_row0_col0, #T_63cbe_row1_col0, #T_63cbe_row2_col0, #T_63cbe_row3_col0, #T_63cbe_row4_col0, #T_63cbe_row5_col0, #T_63cbe_row6_col0, #T_63cbe_row7_col0, #T_63cbe_row8_col0, #T_63cbe_row9_col0, #T_63cbe_row10_col0, #T_63cbe_row11_col0, #T_63cbe_row12_col0, #T_63cbe_row13_col0, #T_63cbe_row14_col0, #T_63cbe_row15_col0, #T_63cbe_row16_col0, #T_63cbe_row17_col0, #T_63cbe_row18_col0, #T_63cbe_row19_col0, #T_63cbe_row20_col0, #T_63cbe_row21_col0 {
#   text-align: left;
# }
# #T_63cbe_row22_col0, #T_63cbe_row23_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %% [markdown]
# **KL661 AMS --> IAH**

# %%
departure_airport = 'AMS'
arrival_airport = 'IAH'
month = 'JAN'
year = '2024'

results_reader = ResultsReaderBaseline(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_baseline_results(df)
# Out:
# <style type="text/css">
# #T_7de3b th.col-1 {
#   text-align: left;
# }
# #T_7de3b td.col-1 {
#   text-align: center;
# }
# #T_7de3b_row0_col0, #T_7de3b_row1_col0, #T_7de3b_row2_col0, #T_7de3b_row3_col0, #T_7de3b_row4_col0, #T_7de3b_row5_col0, #T_7de3b_row6_col0 {
#   text-align: left;
# }
# #T_7de3b_row7_col0, #T_7de3b_row8_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %%
departure_airport = 'AMS'
arrival_airport = 'IAH'
month = 'FEB'
year = '2024'

results_reader = ResultsReaderBaseline(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_baseline_results(df)
# Out:
# <style type="text/css">
# #T_8ecc5 th.col-1 {
#   text-align: left;
# }
# #T_8ecc5 td.col-1 {
#   text-align: center;
# }
# #T_8ecc5_row0_col0, #T_8ecc5_row1_col0, #T_8ecc5_row2_col0, #T_8ecc5_row3_col0, #T_8ecc5_row4_col0, #T_8ecc5_row5_col0, #T_8ecc5_row6_col0, #T_8ecc5_row7_col0, #T_8ecc5_row8_col0, #T_8ecc5_row9_col0, #T_8ecc5_row10_col0, #T_8ecc5_row11_col0, #T_8ecc5_row12_col0, #T_8ecc5_row13_col0, #T_8ecc5_row14_col0 {
#   text-align: left;
# }
# #T_8ecc5_row15_col0, #T_8ecc5_row16_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %%
departure_airport = 'AMS'
arrival_airport = 'IAH'
month = 'MAR'
year = '2024'

results_reader = ResultsReaderBaseline(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_baseline_results(df)
# Out:
# <style type="text/css">
# #T_99c12 th.col-1 {
#   text-align: left;
# }
# #T_99c12 td.col-1 {
#   text-align: center;
# }
# #T_99c12_row0_col0, #T_99c12_row1_col0, #T_99c12_row2_col0, #T_99c12_row3_col0, #T_99c12_row4_col0, #T_99c12_row5_col0, #T_99c12_row6_col0, #T_99c12_row7_col0, #T_99c12_row8_col0, #T_99c12_row9_col0, #T_99c12_row10_col0, #T_99c12_row11_col0, #T_99c12_row12_col0, #T_99c12_row13_col0, #T_99c12_row14_col0, #T_99c12_row15_col0, #T_99c12_row16_col0 {
#   text-align: left;
# }
# #T_99c12_row17_col0, #T_99c12_row18_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %% [markdown]
# **KL835 AMS --> SIN**

# %%
departure_airport = 'AMS'
arrival_airport = 'SIN'
month = 'JAN'
year = '2024'

results_reader = ResultsReaderBaseline(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_baseline_results(df)
# Out:
# <style type="text/css">
# #T_ea1a6 th.col-1 {
#   text-align: left;
# }
# #T_ea1a6 td.col-1 {
#   text-align: center;
# }
# #T_ea1a6_row0_col0, #T_ea1a6_row1_col0, #T_ea1a6_row2_col0, #T_ea1a6_row3_col0, #T_ea1a6_row4_col0, #T_ea1a6_row5_col0, #T_ea1a6_row6_col0, #T_ea1a6_row7_col0, #T_ea1a6_row8_col0, #T_ea1a6_row9_col0, #T_ea1a6_row10_col0, #T_ea1a6_row11_col0, #T_ea1a6_row12_col0 {
#   text-align: left;
# }
# #T_ea1a6_row13_col0, #T_ea1a6_row14_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %%
departure_airport = 'AMS'
arrival_airport = 'SIN'
month = 'FEB'
year = '2024'

results_reader = ResultsReaderBaseline(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_baseline_results(df)
# Out:
# <style type="text/css">
# #T_a57d0 th.col-1 {
#   text-align: left;
# }
# #T_a57d0 td.col-1 {
#   text-align: center;
# }
# #T_a57d0_row0_col0, #T_a57d0_row1_col0, #T_a57d0_row2_col0, #T_a57d0_row3_col0, #T_a57d0_row4_col0, #T_a57d0_row5_col0, #T_a57d0_row6_col0, #T_a57d0_row7_col0, #T_a57d0_row8_col0, #T_a57d0_row9_col0, #T_a57d0_row10_col0, #T_a57d0_row11_col0, #T_a57d0_row12_col0, #T_a57d0_row13_col0, #T_a57d0_row14_col0, #T_a57d0_row15_col0, #T_a57d0_row16_col0, #T_a57d0_row17_col0, #T_a57d0_row18_col0, #T_a57d0_row19_col0, #T_a57d0_row20_col0 {
#   text-align: left;
# }
# #T_a57d0_row21_col0, #T_a57d0_row22_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %%
departure_airport = 'AMS'
arrival_airport = 'SIN'
month = 'MAR'
year = '2024'

results_reader = ResultsReaderBaseline(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_baseline_results(df)
# Out:
# <style type="text/css">
# #T_780f5 th.col-1 {
#   text-align: left;
# }
# #T_780f5 td.col-1 {
#   text-align: center;
# }
# #T_780f5_row0_col0, #T_780f5_row1_col0, #T_780f5_row2_col0, #T_780f5_row3_col0, #T_780f5_row4_col0, #T_780f5_row5_col0, #T_780f5_row6_col0, #T_780f5_row7_col0, #T_780f5_row8_col0, #T_780f5_row9_col0, #T_780f5_row10_col0, #T_780f5_row11_col0, #T_780f5_row12_col0, #T_780f5_row13_col0, #T_780f5_row14_col0, #T_780f5_row15_col0, #T_780f5_row16_col0, #T_780f5_row17_col0, #T_780f5_row18_col0, #T_780f5_row19_col0, #T_780f5_row20_col0 {
#   text-align: left;
# }
# #T_780f5_row21_col0, #T_780f5_row22_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %% [markdown]
# **KL601 AMS --> LAX**

# %%
departure_airport = 'AMS'
arrival_airport = 'LAX'
month = 'JAN'
year = '2024'

results_reader = ResultsReaderBaseline(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_baseline_results(df)
# Out:
# <style type="text/css">
# #T_f092a th.col-1 {
#   text-align: left;
# }
# #T_f092a td.col-1 {
#   text-align: center;
# }
# #T_f092a_row0_col0, #T_f092a_row1_col0, #T_f092a_row2_col0, #T_f092a_row3_col0, #T_f092a_row4_col0, #T_f092a_row5_col0, #T_f092a_row6_col0, #T_f092a_row7_col0, #T_f092a_row8_col0, #T_f092a_row9_col0, #T_f092a_row10_col0, #T_f092a_row11_col0, #T_f092a_row12_col0, #T_f092a_row13_col0, #T_f092a_row14_col0 {
#   text-align: left;
# }
# #T_f092a_row15_col0, #T_f092a_row16_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %%
departure_airport = 'AMS'
arrival_airport = 'LAX'
month = 'FEB'
year = '2024'

results_reader = ResultsReaderBaseline(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_baseline_results(df)
# Out:
# <style type="text/css">
# #T_711a4 th.col-1 {
#   text-align: left;
# }
# #T_711a4 td.col-1 {
#   text-align: center;
# }
# #T_711a4_row0_col0, #T_711a4_row1_col0, #T_711a4_row2_col0, #T_711a4_row3_col0, #T_711a4_row4_col0, #T_711a4_row5_col0, #T_711a4_row6_col0, #T_711a4_row7_col0, #T_711a4_row8_col0, #T_711a4_row9_col0, #T_711a4_row10_col0, #T_711a4_row11_col0, #T_711a4_row12_col0, #T_711a4_row13_col0, #T_711a4_row14_col0, #T_711a4_row15_col0, #T_711a4_row16_col0, #T_711a4_row17_col0 {
#   text-align: left;
# }
# #T_711a4_row18_col0, #T_711a4_row19_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %%
departure_airport = 'AMS'
arrival_airport = 'LAX'
month = 'MAR'
year = '2024'

results_reader = ResultsReaderBaseline(departure_airport, arrival_airport, month, year)
df = results_reader.read_results()
results_reader.style_baseline_results(df)
# Out:
# <style type="text/css">
# #T_88028 th.col-1 {
#   text-align: left;
# }
# #T_88028 td.col-1 {
#   text-align: center;
# }
# #T_88028_row0_col0, #T_88028_row1_col0, #T_88028_row2_col0, #T_88028_row3_col0, #T_88028_row4_col0, #T_88028_row5_col0, #T_88028_row6_col0, #T_88028_row7_col0, #T_88028_row8_col0, #T_88028_row9_col0, #T_88028_row10_col0, #T_88028_row11_col0, #T_88028_row12_col0, #T_88028_row13_col0 {
#   text-align: left;
# }
# #T_88028_row14_col0, #T_88028_row15_col0 {
#   font-weight: bold;
#   text-align: left;
# }
# ...

# %% [markdown]
# **All Flights ICN, IAH, SIN, LAX**

# %%
results_reader = ResultsReaderBaseline()
df = results_reader.read_all_results()
results_reader.style_baseline_results(df)
# Out:
# <style type="text/css">
# #T_54f2f th.col-1 {
#   text-align: left;
# }
# #T_54f2f td.col-1 {
#   text-align: center;
# }
# ...
